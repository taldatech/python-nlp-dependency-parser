# %%
import time
import os
import pickle
import numpy as np
from collections import OrderedDict
from collections import namedtuple
from random import shuffle
import copy
from itertools import combinations, combinations_with_replacement
from utils.utils import ROOT, dep_sample_generator
from typing import List, Dict

# %%
def generate_features_dict(path_to_file, sample2features, start_idx, feature_threshold=0, save_to_file=False,
                           features_name=''):
    """
    This function generates a features dictionary, such that for every features, an index is given starting from start
    the given start_idx.
    The following features are generated for a given dataset:
    byt the given sample2features which is a lambda exprestion to extract a feature from a sample
    you can think of sample2features as a template
    :param: path_to_file: path to location of the dataset (str)
    :param: feature_threshold: if to consider a feature with word that appears less than that in the dataset (int)
    :param: save_to_file: whether or not to save the dictionary on the disk (bool)
    :param: word_hist: dictionary of words histogram in the dataset (dict)
    :return: hw_hp_feat_dict: dictionary feature->index (dict)
    """

    samp_gen = dep_sample_generator(path_to_file)
    hw_hp_feat_dict = OrderedDict()
    features_hist = OrderedDict()

    for s_i, sample in enumerate(samp_gen):
        for s in sample:
            # ignore ROOT
            if s.token == ROOT:
                continue
            

            feats = sample2features(sample, s)
            for feat in feats:
                features_hist[feat] = features_hist.get(feat, 0) + 1

    current_idx = start_idx
    for k, v in features_hist.items():
        if v > feature_threshold:
            hw_hp_feat_dict[k] = current_idx
            current_idx += 1

#     print("total {:} features: ".format(features_name), current_idx)
    hw_hp_feat_dict = OrderedDict(sorted(hw_hp_feat_dict.items(), key=lambda t: t[1]))
    if save_to_file:
        path = path_to_file + features_name + '.dict'
        with open(path, 'wb') as fp:
            pickle.dump(hw_hp_feat_dict, fp)
        print("saved {:} features dictionary @ ".format(features_name), path)
    return hw_hp_feat_dict

# %%
def generate_features_dicts(path_to_file: str, save_to_file: bool =False, minimal: bool=False
                            , use_mcdonald: bool=False)->Dict[str, dict]:
    """
    given a training file we return a dictionary of dictionaries
    where key is feature type name, and value is a dictionary of that feature generated by 'generate_features_dict'
    according to feature templates required by hw2 pg 2, those templates are:
    head word _ head pos
    head word
    head pos
    child word _ child pos
    child word
    child pos
    h_pos c_word c_pos

    if not minimal we add:
        h_word h_pos c_word c_pos
        h_word c_word c_pos
        h_word h_pos c_word
        h_word c_word
        
    if use mcdonald:
        distance(head,child)
        # is head to the right or left of the child:
        1 if head.idx < child.idx
        # in-between POS features:
        (h_pos, b_pos, c_pos)
        # surrounding word POS features:
        (h_pos, h+1_pos, c-1_pos, c_pos)
        (h-1_pos, h_pos, c-1_pos, c_pos)
        (h_pos, h+1_pos, c_pos, c+1_pos)
        (h-1_pos, h_pos, c_pos, c+1_pos)
    :param path_to_file: training file to extract features from
    :param save_to_file: if to save the dictionary
    :param minimal: if to add the extra features as described
    :return: dictionary described above
    """

    feature_types = {'head word _ head pos': (lambda sample, s: [(sample[s.head].token, sample[s.head].pos)], 0),
                     'head word': (lambda sample, s: [(sample[s.head].token)], 0),
                     'head pos': (lambda sample, s: [(sample[s.head].pos)], 0),
                     'child word _ child pos': (lambda sample, s: [(s.token, s.pos)], 0),
                     'child word': (lambda sample, s: [(s.token)], 0),
                     'child pos': (lambda sample, s: [(s.pos)], 0),
                     'h_pos c_word c_pos': (lambda sample, s: [(sample[s.head].pos, s.token, s.pos)], 0),
                     'h_word h_pos c_pos': (lambda sample, s: [(sample[s.head].token, sample[s.head].pos, s.pos)], 0),
                     'h_pos c_pos': (lambda sample, s: [(sample[s.head].pos, s.pos)], 0),
                     }

    if not minimal:

        feature_types['h_word h_pos c_word c_pos'] = (lambda sample, s:
                                                      [(sample[s.head].token, sample[s.head].pos, s.token, s.pos)], 0)

        feature_types['h_word c_word c_pos'] = (lambda sample, s:
                                                [(sample[s.head].token, s.token, s.pos)], 0)

        feature_types['h_word h_pos c_word'] = (lambda sample, s:
                                                [(sample[s.head].token, sample[s.head].pos, s.token)], 0)

        feature_types['h_word c_word'] = (lambda sample, s:
                                          [(sample[s.head].token, s.token)], 0)
        
    if use_mcdonald:
        # distance + is head to the right of child? (-) if child > head, (+) else
        # maybe we can add the distance to the unigrams?
        feature_types['h_word c_word dist'] = (lambda sample, s:
                                                      [(sample[s.head].token, s.token, sample[s.head].idx - s.idx)], 0)
        # in-between POS features:
        feature_types['h_c_pos_seq'] = (lambda sample, s:
                                                      [tuple(l.pos for l in sample[sample[s.head].idx : s.idx + 1])], 0)
        # surrounding word POS features
        feature_types['h_pos h_next_pos c_prev_pos c_pos'] = (lambda sample, s:
                                                              [(sample[s.head].pos,
                                                                sample[min(s.head + 1, sample[-1].idx)].pos,
                                                                sample[max(s.idx - 1, 0)].pos,
                                                                s.pos)], 0)
        
        feature_types['h_prev_pos h_pos c_prev_pos c_pos'] = (lambda sample, s:
                                                              [(sample[max(s.head - 1, 0)].pos,
                                                                sample[s.head].pos,
                                                                sample[max(s.idx - 1, 0)].pos,
                                                                s.pos)], 0)
        
        feature_types['h_pos h_next_pos c_pos c_next_pos'] = (lambda sample, s:
                                                              [(sample[s.head].pos,
                                                                sample[min(s.head + 1, sample[-1].idx)].pos,
                                                                s.pos,
                                                                sample[min(s.idx + 1, sample[-1].idx)].pos)], 0)
        
        feature_types['h_prev_pos h_pos c_pos c_next_pos'] = (lambda sample, s:
                                                              [(sample[max(s.head - 1, 0)].pos,
                                                                sample[s.head].pos,
                                                                s.pos,
                                                                sample[min(s.idx + 1, sample[-1].idx)].pos)], 0)
    features_dicts = {}
    current_num_features = 0
    for feature_type_name, (feature_template, feature_threshold) in feature_types.items():

        features_dicts[feature_type_name] = generate_features_dict(path_to_file,
                                                                   feature_template,
                                                                   start_idx=current_num_features,
                                                                   feature_threshold=feature_threshold,
                                                                   save_to_file=False,
                                                                   features_name=feature_type_name)

        num_features = len(features_dicts[feature_type_name])
        current_num_features += num_features

        print('generated {:} features , num features: {:}, total num features: {:}'.format(feature_type_name,
                                                                                         num_features,
                                                                                         current_num_features))

    return features_dicts

# %%
dictionaries = generate_features_dicts('./data/train.labeled.train.labeled', use_mcdonald=True)
# Out:
# generated h_pos c_word c_pos features , num features: 26559, total num features: 26559
# generated h_word h_pos c_word c_pos features , num features: 58981, total num features: 85540
# generated h_word h_pos c_word features , num features: 58614, total num features: 144154
# generated h_pos h_next_pos c_pos c_next_pos features , num features: 16465, total num features: 160619
# generated head pos features , num features: 36, total num features: 160655
# generated child word _ child pos features , num features: 13641, total num features: 174296
# generated h_c_pos_seq features , num features: 17414, total num features: 191710
# generated head word _ head pos features , num features: 8595, total num features: 200305
# generated head word features , num features: 7669, total num features: 207974
# generated h_pos c_pos features , num features: 711, total num features: 208685
# generated h_pos h_next_pos c_prev_pos c_pos features , num features: 15998, total num features: 224683
# generated h_word c_word dist features , num features: 68440, total num features: 293123
# generated child word features , num features: 12218, total num features: 305341
# generated h_prev_pos h_pos c_pos c_next_pos features , num features: 16662, total num features: 322003
# generated h_word c_word features , num features: 57981, total num features: 379984
# generated child pos features , num features: 45, total num features: 380029
# generated h_word c_word c_pos features , num features: 58363, total num features: 438392
# generated h_prev_pos h_pos c_prev_pos c_pos features , num features: 15127, total num features: 453519
# generated h_word h_pos c_pos features , num features: 28735, total num features: 482254

# %%
dictionaries.keys()
# Out:
# dict_keys(['h_pos c_word c_pos', 'h_word h_pos c_word c_pos', 'h_word h_pos c_word', 'h_pos h_next_pos c_pos c_next_pos', 'head pos', 'child word _ child pos', 'h_c_pos_seq', 'head word _ head pos', 'head word', 'h_pos c_pos', 'h_pos h_next_pos c_prev_pos c_pos', 'h_word c_word dist', 'child word', 'h_prev_pos h_pos c_pos c_next_pos', 'h_word c_word', 'child pos', 'h_word c_word c_pos', 'h_prev_pos h_pos c_prev_pos c_pos', 'h_word h_pos c_pos'])

# %%
sample = next(dep_sample_generator('./data/train.labeled.train.labeled'))
sample
child = sample[6]
head = sample[child.head]

# %%
dict2check = 'child word _ child pos'

# %%
a = dictionaries['h_word c_word'].get((head.token, child.token))
a
# Out:
# 187029

# %%
dictionaries['h_c_pos_seq']
# Out:
# OrderedDict([((), 174296),
#              (('NNP', ','), 174297),
#              (('NNP', ',', 'CD', 'NNS', 'JJ'), 174298),
#              (('NNP', ',', 'CD', 'NNS', 'JJ', ','), 174299),
#              (('*', 'NNP', 'NNP', ',', 'CD', 'NNS', 'JJ', ',', 'MD'), 174300),
#              (('MD', 'VB'), 174301),
#              (('VB', 'DT', 'NN'), 174302),
#              (('VB', 'DT', 'NN', 'IN'), 174303),
#              (('IN', 'DT', 'JJ', 'NN'), 174304),
#              (('VB', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN', 'NNP'), 174305),
#              (('NNP', 'CD'), 174306),
#              (('MD',
#                'VB',
#                'DT',
#                'NN',
#                'IN',
#                'DT',
#                'JJ',
#                'NN',
#                'NNP',
#                'CD',
#                '.'),
#               174307),
#              (('*', 'NNP', 'NNP', 'VBZ'), 174308),
#              (('VBZ', 'NN'), 174309),
#              (('NN', 'IN'), 174310),
#              (('IN', 'NNP', 'NNP'), 174311),
#              (('NNP', ',', 'DT', 'NNP', 'VBG', 'NN'), 174312),
#              (('VBZ',
#                'NN',
#                'IN',
#                'NNP',
#                'NNP',
#                ',',
#                'DT',
#                'NNP',
#                'VBG',
#                'NN',
#                '.'),
#               174313),
#              (('JJ', 'CC'), 174314),
#              (('CC', 'JJ', 'NN'), 174315),
#              (('IN', 'NNP', 'NNP', 'NNP', 'NNP'), 174316),
#              (('NNP',
#                ',',
#                'CD',
#                'NNS',
#                'JJ',
#                'CC',
#                'JJ',
#                'NN',
#                'IN',
#                'NNP',
#                'NNP',
#                'NNP',
#                'NNP',
#                ','),
#               174317),
#              (('*',
#                'NNP',
#                'NNP',
#                ',',
#                'CD',
#                'NNS',
#                'JJ',
#                'CC',
#                'JJ',
#                'NN',
#                'IN',
#                'NNP',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'VBD'),
#               174318),
#              (('VBD', 'VBN'), 174319),
#              (('VBN', 'DT', 'JJ', 'NN'), 174320),
#              (('IN', 'DT', 'JJ', 'JJ', 'NN'), 174321),
#              (('VBD',
#                'VBN',
#                'DT',
#                'JJ',
#                'NN',
#                'IN',
#                'DT',
#                'JJ',
#                'JJ',
#                'NN',
#                '.'),
#               174322),
#              (('IN', 'NN'), 174323),
#              (('NN', 'IN', 'NN', 'RB', 'VBN'), 174324),
#              (('VBN', 'TO'), 174325),
#              (('TO', 'VB'), 174326),
#              (('VB', 'NNP', 'NN', 'NNS'), 174327),
#              (('VBZ', 'VBN'), 174328),
#              (('IN', 'NN', 'NNS'), 174329),
#              (('NN', 'IN', 'NN', 'NNS', 'IN'), 174330),
#              (('IN', 'DT', 'NN'), 174331),
#              (('IN', 'NNS'), 174332),
#              (('NNS', 'VBN'), 174333),
#              (('TO', 'PRP'), 174334),
#              (('VBN', 'TO', 'PRP', 'RBR', 'IN', 'CD', 'NNS', 'IN'), 174335),
#              (('*',
#                'DT',
#                'NN',
#                'IN',
#                'NN',
#                'RB',
#                'VBN',
#                'TO',
#                'VB',
#                'NNP',
#                'NN',
#                'NNS',
#                'VBZ',
#                'VBN',
#                'DT',
#                'JJ',
#                'NN',
#                'IN',
#                'NN',
#                'NNS',
#                'IN',
#                'DT',
#                'NN',
#                'IN',
#                'NNS',
#                'VBN',
#                'TO',
#                'PRP',
#                'RBR',
#                'IN',
#                'CD',
#                'NNS',
#                'IN',
#                ',',
#                'NNS',
#                'VBD'),
#               174336),
#              (('VBD', '.'), 174337),
#              (('NN', ','), 174338),
#              (('NN', ',', 'NN'), 174339),
#              (('NN', ',', 'NN', ','), 174340),
#              (('VBZ', 'RB', 'JJ'), 174341),
#              (('VBZ', 'RB', 'JJ', 'IN'), 174342),
#              (('IN', 'PRP', 'VBZ'), 174343),
#              (('VBZ', 'DT', 'NNS'), 174344),
#              (('VBZ', 'RB', 'JJ', 'IN', 'PRP', 'VBZ', 'DT', 'NNS', ','),
#               174345),
#              (('VBZ', 'RB', 'JJ', 'IN', 'PRP', 'VBZ', 'DT', 'NNS', ',', 'IN'),
#               174346),
#              (('NNS', 'TO'), 174347),
#              (('IN', 'RB', 'JJ', 'NNS', 'TO', 'PRP', 'VBG'), 174348),
#              (('VBG', 'NNS'), 174349),
#              (('NNS', 'WDT', 'VBP'), 174350),
#              (('VBP', 'RP'), 174351),
#              (('VBP', 'RP', 'NNS', 'JJ'), 174352),
#              (('*',
#                'DT',
#                'NN',
#                'NN',
#                ',',
#                'NN',
#                ',',
#                'VBZ',
#                'RB',
#                'JJ',
#                'IN',
#                'PRP',
#                'VBZ',
#                'DT',
#                'NNS',
#                ',',
#                'IN',
#                'RB',
#                'JJ',
#                'NNS',
#                'TO',
#                'PRP',
#                'VBG',
#                'NNS',
#                'WDT',
#                'VBP',
#                'RP',
#                'NNS',
#                'JJ',
#                ',',
#                'NNS',
#                'VBD'),
#               174353),
#              (('NNP', ',', 'DT', 'NN'), 174354),
#              (('IN', 'JJ', 'JJ', 'NNP', 'NNP'), 174355),
#              (('NN', 'IN', 'JJ', 'JJ', 'NNP', 'NNP', 'WDT', 'VBZ'), 174356),
#              (('VBZ', 'NNP', 'NNS'), 174357),
#              (('NNP',
#                ',',
#                'DT',
#                'NN',
#                'IN',
#                'JJ',
#                'JJ',
#                'NNP',
#                'NNP',
#                'WDT',
#                'VBZ',
#                'NNP',
#                'NNS',
#                ','),
#               174358),
#              (('*',
#                'NNP',
#                'NNP',
#                ',',
#                'DT',
#                'NN',
#                'IN',
#                'JJ',
#                'JJ',
#                'NNP',
#                'NNP',
#                'WDT',
#                'VBZ',
#                'NNP',
#                'NNS',
#                ',',
#                'VBD'),
#               174359),
#              (('VBD', 'VBG'), 174360),
#              (('VBG', 'NN'), 174361),
#              (('VBG', 'NN', 'IN'), 174362),
#              (('IN', 'PRP$', 'NN', 'NN', 'NNS'), 174363),
#              (('VBG', 'NN', 'IN', 'PRP$', 'NN', 'NN', 'NNS', 'IN'), 174364),
#              (('IN', 'CD'), 174365),
#              (('VBD',
#                'VBG',
#                'NN',
#                'IN',
#                'PRP$',
#                'NN',
#                'NN',
#                'NNS',
#                'IN',
#                'CD',
#                '.'),
#               174366),
#              (('IN', 'JJ', 'NNS', 'VBD'), 174367),
#              (('VBN', 'RBR', 'IN', 'DT', 'NN', 'IN'), 174368),
#              (('*',
#                'IN',
#                'JJ',
#                'NNS',
#                'VBD',
#                'VBN',
#                'RBR',
#                'IN',
#                'DT',
#                'NN',
#                'IN',
#                ',',
#                'DT',
#                'JJS',
#                'NNS',
#                'VBP'),
#               174369),
#              (('VBP', 'IN'), 174370),
#              (('NN', 'POS'), 174371),
#              (('IN', 'NN', 'POS', 'NNP', 'NNP', 'NNP'), 174372),
#              (('NNP', 'IN'), 174373),
#              (('IN', 'NNP'), 174374),
#              (('NNP', 'IN', 'NNP', ','), 174375),
#              (('NNP', 'IN', 'NNP', ',', 'DT', 'NN'), 174376),
#              (('NN', 'JJ'), 174377),
#              (('JJ', 'TO'), 174378),
#              (('VB', 'JJ', 'NN'), 174379),
#              (('VB', 'JJ', 'NN', 'TO'), 174380),
#              (('TO', 'DT', 'NN'), 174381),
#              (('VBP',
#                'IN',
#                'NN',
#                'POS',
#                'NNP',
#                'NNP',
#                'NNP',
#                'IN',
#                'NNP',
#                ',',
#                'DT',
#                'NN',
#                'JJ',
#                'TO',
#                'VB',
#                'JJ',
#                'NN',
#                'TO',
#                'DT',
#                'NN',
#                '.'),
#               174382),
#              (('*', 'DT', 'NNP', 'NN', 'VBD'), 174383),
#              (('VBD', ','), 174384),
#              (('VBD', ',', '``'), 174385),
#              (('VBD', ',', '``', 'DT', 'VBZ'), 174386),
#              (('VBZ', 'DT', 'JJ', 'NN'), 174387),
#              (('VBD', ',', '``', 'DT', 'VBZ', 'DT', 'JJ', 'NN', '.'), 174388),
#              (('*', 'PRP', 'VBP'), 174389),
#              (('VBP', 'VBG'), 174390),
#              (('VBG', 'IN'), 174391),
#              (('IN', 'NNS', 'IN'), 174392),
#              (('IN', 'IN'), 174393),
#              (('IN', 'NN', 'VBD'), 174394),
#              (('VBD', 'IN'), 174395),
#              (('IN', 'NN', 'VBG'), 174396),
#              (('VBG', 'DT', 'JJ', 'NNS'), 174397),
#              (('VBP',
#                'VBG',
#                'IN',
#                'NNS',
#                'IN',
#                'IN',
#                'NN',
#                'VBD',
#                'IN',
#                'NN',
#                'VBG',
#                'DT',
#                'JJ',
#                'NNS',
#                '.'),
#               174398),
#              (('*', 'EX', 'VBZ'), 174399),
#              (('VBZ', 'DT', 'NN'), 174400),
#              (('VBZ', 'DT', 'NN', 'IN'), 174401),
#              (('IN', 'PRP$', 'NNS'), 174402),
#              (('VBZ', 'DT', 'NN', 'IN', 'PRP$', 'NNS', 'RB'), 174403),
#              (('VBZ', 'DT', 'NN', 'IN', 'PRP$', 'NNS', 'RB', '.'), 174404),
#              (('VBZ', 'DT', 'NN', 'IN', 'PRP$', 'NNS', 'RB', '.', "''"),
#               174405),
#              (('NNP', 'CC'), 174406),
#              (('CC', 'DT', 'NNS'), 174407),
#              (('NNS', 'WP', 'VBD'), 174408),
#              (('VBD', 'DT', 'NNS'), 174409),
#              (('*',
#                'DT',
#                'NNP',
#                'CC',
#                'DT',
#                'NNS',
#                'WP',
#                'VBD',
#                'DT',
#                'NNS',
#                'VBD'),
#               174410),
#              (('VBD', 'JJ'), 174411),
#              (('JJ', 'IN'), 174412),
#              (('NNS', 'IN'), 174413),
#              (('IN', 'DT', 'NNP', 'NNS'), 174414),
#              (('VBD',
#                'JJ',
#                'IN',
#                'DT',
#                'NN',
#                'IN',
#                'NNS',
#                'IN',
#                'DT',
#                'NNP',
#                'NNS',
#                '.'),
#               174415),
#              (('VBP', 'DT', 'JJ', 'NN'), 174416),
#              (('IN', 'NNS', 'VBP'), 174417),
#              (('*',
#                '``',
#                'PRP',
#                'VBP',
#                'DT',
#                'JJ',
#                'NN',
#                'IN',
#                'IN',
#                'NNS',
#                'VBP',
#                'IN',
#                'NN',
#                ',',
#                "''",
#                'VBD'),
#               174418),
#              (('VBD', 'NNP', 'NNP', 'NNP'), 174419),
#              (('NNP', 'POS'), 174420),
#              (('IN', 'NNP', 'POS', 'NNP', 'NNP', 'NNP'), 174421),
#              (('VBD',
#                'NNP',
#                'NNP',
#                'NNP',
#                'IN',
#                'NNP',
#                'POS',
#                'NNP',
#                'NNP',
#                'NNP',
#                '.'),
#               174422),
#              (('*', 'NNP', 'NNP', 'VBD'), 174423),
#              (('VBD', 'DT', 'NN'), 174424),
#              (('IN', 'DT', 'NNP', 'NNP', 'NNP'), 174425),
#              (('CC', 'DT', 'JJ', 'NNS'), 174426),
#              (('CC', 'NNP', 'NNP'), 174427),
#              (('VBD',
#                'DT',
#                'NN',
#                'IN',
#                'NNS',
#                'IN',
#                'DT',
#                'NNP',
#                'NNP',
#                'NNP',
#                'CC',
#                'DT',
#                'JJ',
#                'NNS',
#                'IN',
#                'NNP',
#                'NNP',
#                'CC',
#                'NNP',
#                'NNP',
#                '.'),
#               174428),
#              (('VBD', 'NN', 'VBD'), 174429),
#              (('VBN', 'IN'), 174430),
#              (('IN', '``'), 174431),
#              (('IN', '``', 'RB', 'JJ', 'NNS'), 174432),
#              (('IN', '``', 'RB', 'JJ', 'NNS', "''"), 174433),
#              (('VBN', 'IN', '``', 'RB', 'JJ', 'NNS', "''", 'IN'), 174434),
#              (('IN', 'VBG'), 174435),
#              (('IN', 'DT', 'NNS'), 174436),
#              (('VBN',
#                'IN',
#                '``',
#                'RB',
#                'JJ',
#                'NNS',
#                "''",
#                'IN',
#                'VBG',
#                'NN',
#                'IN',
#                'DT',
#                'NNS',
#                'IN'),
#               174437),
#              (('IN', 'DT', 'JJ', 'CD'), 174438),
#              (('VBN',
#                'IN',
#                '``',
#                'RB',
#                'JJ',
#                'NNS',
#                "''",
#                'IN',
#                'VBG',
#                'NN',
#                'IN',
#                'DT',
#                'NNS',
#                'IN',
#                'DT',
#                'JJ',
#                'CD',
#                'CC'),
#               174439),
#              (('CC', 'VBN'), 174440),
#              (('VBN', 'IN', 'DT', 'JJ', 'NN', 'IN', 'NN', 'IN'), 174441),
#              (('VBD',
#                'NN',
#                'VBD',
#                'VBN',
#                'IN',
#                '``',
#                'RB',
#                'JJ',
#                'NNS',
#                "''",
#                'IN',
#                'VBG',
#                'NN',
#                'IN',
#                'DT',
#                'NNS',
#                'IN',
#                'DT',
#                'JJ',
#                'CD',
#                'CC',
#                'VBN',
#                'IN',
#                'DT',
#                'JJ',
#                'NN',
#                'IN',
#                'NN',
#                'IN',
#                'CD',
#                '.'),
#               174442),
#              (('IN', 'CD', 'TO'), 174443),
#              (('TO', 'CD'), 174444),
#              (('*',
#                'IN',
#                'CD',
#                'TO',
#                'CD',
#                ',',
#                'CD',
#                'CD',
#                'NNP',
#                'NNS',
#                'IN',
#                'DT',
#                'NNS',
#                'VBD',
#                'VBN',
#                ',',
#                'DT',
#                'NN',
#                'VBD'),
#               174445),
#              (('IN', 'CD', 'NNS'), 174446),
#              (('VBD', 'RB'), 174447),
#              (('VBD', 'RB', 'IN'), 174448),
#              (('*',
#                'IN',
#                'CD',
#                'NNS',
#                'WP',
#                'VBD',
#                'RB',
#                'IN',
#                'DT',
#                'NN',
#                ',',
#                'CD',
#                'VBP'),
#               174449),
#              (('VBP', 'VBN'), 174450),
#              (('VBN', ':'), 174451),
#              (('VBN', ':', 'JJ', 'IN', 'CD', 'NNS', 'DT', 'VBN', 'NN'),
#               174452),
#              (('VBP',
#                'VBN',
#                ':',
#                'JJ',
#                'IN',
#                'CD',
#                'NNS',
#                'DT',
#                'VBN',
#                'NN',
#                '.'),
#               174453),
#              (('CD', 'IN'), 174454),
#              (('IN', 'DT', 'CD', 'VBG', 'NNS'), 174455),
#              (('*', 'CD', 'IN', 'DT', 'CD', 'VBG', 'NNS', 'VBP'), 174456),
#              (('VBP', 'JJ', 'NNS'), 174457),
#              (('VBP', 'JJ', 'NNS', ','), 174458),
#              (('VBP', 'JJ', 'NNS', ',', 'VBG'), 174459),
#              (('VBG', 'CD'), 174460),
#              (('IN', 'RB', 'VBN', 'NN'), 174461),
#              (('VBP',
#                'JJ',
#                'NNS',
#                ',',
#                'VBG',
#                'CD',
#                'IN',
#                'RB',
#                'VBN',
#                'NN',
#                '.'),
#               174462),
#              (('IN', 'JJ', 'NN'), 174463),
#              (('NN', ',', 'NN', 'NN'), 174464),
#              (('NN', 'CC'), 174465),
#              (('CC', 'NN'), 174466),
#              (('VBD', 'RB', 'JJR'), 174467),
#              (('JJR', 'IN'), 174468),
#              (('IN', 'VBN'), 174469),
#              (('*',
#                'DT',
#                'NN',
#                'IN',
#                'CD',
#                'NNS',
#                'IN',
#                'JJ',
#                'NN',
#                ',',
#                'NN',
#                'NN',
#                'CC',
#                'NN',
#                'VBD',
#                'RB',
#                'JJR',
#                'IN',
#                'VBN',
#                ',',
#                'DT',
#                'NNS',
#                'VBD'),
#               174470),
#              (('VBZ', 'DT', 'JJ', 'NN', 'IN'), 174471),
#              (('IN', 'DT'), 174472),
#              (('DT', 'IN'), 174473),
#              (('IN', 'PRP'), 174474),
#              (('DT', 'IN', 'PRP', 'WP', 'VBP'), 174475),
#              (('*',
#                '``',
#                'DT',
#                'NN',
#                'NN',
#                'VBZ',
#                'DT',
#                'JJ',
#                'NN',
#                'IN',
#                'DT',
#                'IN',
#                'PRP',
#                'WP',
#                'VBP',
#                'JJ',
#                'NNS',
#                ',',
#                "''",
#                'VBD'),
#               174476),
#              (('VBD', 'NNP', 'NNP'), 174477),
#              (('VBD', 'NNP', 'NNP', '.'), 174478),
#              (('IN', 'NN', 'NN', 'NNS'), 174479),
#              (('NN', 'IN', 'NN', 'NN', 'NNS', 'IN'), 174480),
#              (('IN', 'DT', 'NNP', 'NNP', ',', 'NNP', ',', 'NN', 'NN'), 174481),
#              (('VBZ', 'TO'), 174482),
#              (('VB', 'DT', 'JJS'), 174483),
#              (('JJS', 'IN'), 174484),
#              (('IN', 'DT', 'NN', 'NNS'), 174485),
#              (('IN', 'JJ', 'VBN', 'NNS'), 174486),
#              (('*',
#                'DT',
#                'NN',
#                'IN',
#                'NN',
#                'NN',
#                'NNS',
#                'IN',
#                'DT',
#                'NNS',
#                'IN',
#                'DT',
#                'NNP',
#                'NNP',
#                ',',
#                'NNP',
#                ',',
#                'NN',
#                'NN',
#                'VBZ',
#                'TO',
#                'VB',
#                'DT',
#                'JJS',
#                'IN',
#                'DT',
#                'NN',
#                'NNS',
#                'VBN',
#                'IN',
#                'JJ',
#                'VBN',
#                'NNS',
#                ',',
#                'PRP',
#                'VBD'),
#               174487),
#              (('NN', ',', 'WDT', 'VBZ'), 174488),
#              (('CC', 'NNP'), 174489),
#              (('IN', 'NNP', 'CC', 'NNP', 'NNP'), 174490),
#              (('NN',
#                ',',
#                'WDT',
#                'VBZ',
#                'VBN',
#                'IN',
#                'NNP',
#                'CC',
#                'NNP',
#                'NNP',
#                ','),
#               174491),
#              (('*',
#                'DT',
#                'NN',
#                ',',
#                'WDT',
#                'VBZ',
#                'VBN',
#                'IN',
#                'NNP',
#                'CC',
#                'NNP',
#                'NNP',
#                ',',
#                'VBD'),
#               174492),
#              (('NN', 'IN', 'NN', 'TO'), 174493),
#              (('VB', 'DT', 'NN', 'NNS'), 174494),
#              (('VBD',
#                'IN',
#                'NN',
#                'IN',
#                'NN',
#                'TO',
#                'VB',
#                'DT',
#                'NN',
#                'NNS',
#                '.'),
#               174495),
#              (('VB', 'DT'), 174496),
#              (('DT', 'WP', 'VBP'), 174497),
#              (('IN', 'DT', 'NNP', 'MD'), 174498),
#              (('NN', 'IN', 'NN', 'VBG'), 174499),
#              (('VB', 'DT', 'NN', 'IN', 'NN', 'VBG', 'NN', 'RBR', 'RB'),
#               174500),
#              (('RB', 'IN'), 174501),
#              (('NN', 'IN', 'NN', ','), 174502),
#              (('NN', 'IN', 'NN', ',', 'NN'), 174503),
#              (('NN', 'IN', 'NN', ',', 'NN', ','), 174504),
#              (('NN', 'IN', 'NN', ',', 'NN', ',', 'VBN'), 174505),
#              (('IN', 'JJS', 'NNS'), 174506),
#              (('NNS', 'CC'), 174507),
#              (('CC', 'JJ', 'NNS'), 174508),
#              (('*',
#                'DT',
#                'NN',
#                'RB',
#                'MD',
#                'VB',
#                'DT',
#                'WP',
#                'VBP',
#                'IN',
#                'DT',
#                'NNP',
#                'MD',
#                'VB',
#                'DT',
#                'NN',
#                'IN',
#                'NN',
#                'VBG',
#                'NN',
#                'RBR',
#                'RB',
#                'IN',
#                'DT',
#                'JJ',
#                'NN',
#                'IN',
#                'NN',
#                ',',
#                'NN',
#                ',',
#                'VBN',
#                'IN',
#                'JJS',
#                'NNS',
#                'CC',
#                'JJ',
#                'NNS',
#                ',',
#                'NNP',
#                'NNP',
#                'VBD'),
#               174509),
#              (('*', 'DT', 'NNP', 'VBZ'), 174510),
#              (('VBZ', 'CD'), 174511),
#              (('IN', 'DT', 'JJ', 'VBN', 'NNS'), 174512),
#              (('NNS', 'WDT', 'VBZ'), 174513),
#              (('VBZ', 'RB'), 174514),
#              (('VBZ', 'RB', 'VB'), 174515),
#              (('VB', 'DT', 'JJR', 'NN'), 174516),
#              (('NN', 'IN', 'NN', 'IN'), 174517),
#              (('IN', 'DT', 'JJ', ',', 'JJ', 'NNS'), 174518),
#              (('NNS', 'JJ', 'IN'), 174519),
#              (('NNS', 'JJ', 'IN', 'NN', 'WDT', 'VBP'), 174520),
#              (('VBZ',
#                'CD',
#                'IN',
#                'DT',
#                'JJ',
#                'VBN',
#                'NNS',
#                'WDT',
#                'VBZ',
#                'RB',
#                'VB',
#                'DT',
#                'JJR',
#                'NN',
#                'IN',
#                'NN',
#                'IN',
#                'DT',
#                'JJ',
#                ',',
#                'JJ',
#                'NNS',
#                'JJ',
#                'IN',
#                'NN',
#                'WDT',
#                'VBP',
#                'VBN',
#                'IN',
#                'NNS',
#                ','),
#               174521),
#              (('VBZ',
#                'CD',
#                'IN',
#                'DT',
#                'JJ',
#                'VBN',
#                'NNS',
#                'WDT',
#                'VBZ',
#                'RB',
#                'VB',
#                'DT',
#                'JJR',
#                'NN',
#                'IN',
#                'NN',
#                'IN',
#                'DT',
#                'JJ',
#                ',',
#                'JJ',
#                'NNS',
#                'JJ',
#                'IN',
#                'NN',
#                'WDT',
#                'VBP',
#                'VBN',
#                'IN',
#                'NNS',
#                ',',
#                'VBG'),
#               174522),
#              (('VBG', 'TO'), 174523),
#              (('TO', 'NNP', 'NNP', 'NNP'), 174524),
#              (('IN', 'DT', 'NNP', 'IN', 'NNP', 'NNP'), 174525),
#              (('VBZ',
#                'CD',
#                'IN',
#                'DT',
#                'JJ',
#                'VBN',
#                'NNS',
#                'WDT',
#                'VBZ',
#                'RB',
#                'VB',
#                'DT',
#                'JJR',
#                'NN',
#                'IN',
#                'NN',
#                'IN',
#                'DT',
#                'JJ',
#                ',',
#                'JJ',
#                'NNS',
#                'JJ',
#                'IN',
#                'NN',
#                'WDT',
#                'VBP',
#                'VBN',
#                'IN',
#                'NNS',
#                ',',
#                'VBG',
#                'TO',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'DT',
#                'NN',
#                'IN',
#                'NN',
#                'IN',
#                'DT',
#                'NNP',
#                'IN',
#                'NNP',
#                'NNP',
#                'IN',
#                'NNP',
#                '.'),
#               174526),
#              (('VBP', 'JJ'), 174527),
#              (('VBP', 'JJ', 'CC'), 174528),
#              (('CC', 'VBP'), 174529),
#              (('VBP', 'RBR', 'RB', 'VBN'), 174530),
#              (('*',
#                'RBR',
#                'JJ',
#                'NN',
#                'NNS',
#                'VBP',
#                'JJ',
#                'CC',
#                'VBP',
#                'RBR',
#                'RB',
#                'VBN',
#                'IN',
#                'DT',
#                'NN',
#                ',',
#                'NNP',
#                'NNP',
#                'VBD'),
#               174531),
#              (('*', 'IN', 'NNP', ',', 'DT', 'NNP', 'NNP', 'NNP', 'VBD'),
#               174532),
#              (('VBD', 'DT', 'JJ', 'NN'), 174533),
#              (('VBD', 'DT', 'JJ', 'NN', 'IN'), 174534),
#              (('IN', 'RB', 'DT', 'NNS'), 174535),
#              (('VBD',
#                'DT',
#                'JJ',
#                'NN',
#                'IN',
#                'RB',
#                'DT',
#                'NNS',
#                'IN',
#                'NN',
#                '.'),
#               174536),
#              (('*',
#                'IN',
#                'CD',
#                ',',
#                'RB',
#                'DT',
#                'VBG',
#                'NNS',
#                'IN',
#                'JJ',
#                'NN',
#                'MD'),
#               174537),
#              (('VB', 'VBN'), 174538),
#              (('MD', 'VB', 'VBN', '.'), 174539),
#              (('NN', 'WDT', 'VBD'), 174540),
#              (('VBD', 'NN'), 174541),
#              (('*',
#                'IN',
#                'CD',
#                'NNS',
#                'IN',
#                'DT',
#                'NN',
#                'WDT',
#                'VBD',
#                'NN',
#                'IN',
#                'DT',
#                'NNP',
#                'NNS',
#                'VBD'),
#               174542),
#              (('TO', 'NN'), 174543),
#              (('VBN', 'TO', 'NN', 'IN'), 174544),
#              (('IN', 'DT', 'CD'), 174545),
#              (('VBD', 'VBN', 'TO', 'NN', 'IN', 'DT', 'CD', '.'), 174546),
#              (('*', 'NNS', 'IN', 'DT', 'NN', 'VBD'), 174547),
#              (('VBD', 'RB', 'JJ'), 174548),
#              (('VBD', 'RB', 'JJ', 'WRB', 'DT', 'NN', 'VBD'), 174549),
#              (('VBD', 'RB', 'JJ', 'WRB', 'DT', 'NN', 'VBD', 'VBN', '.'),
#               174550),
#              (('*', 'NNS', 'VBD'), 174551),
#              (('VBD', 'JJ', 'NN', 'NNS'), 174552),
#              (('IN', 'DT', 'VBN', 'NN'), 174553),
#              (('VBD', 'JJ', 'NN', 'NNS', 'IN', 'DT', 'VBN', 'NN', 'IN'),
#               174554),
#              (('VBD',
#                'JJ',
#                'NN',
#                'NNS',
#                'IN',
#                'DT',
#                'VBN',
#                'NN',
#                'IN',
#                'DT',
#                'JJ',
#                'NN',
#                ','),
#               174555),
#              (('VBD',
#                'JJ',
#                'NN',
#                'NNS',
#                'IN',
#                'DT',
#                'VBN',
#                'NN',
#                'IN',
#                'DT',
#                'JJ',
#                'NN',
#                ',',
#                'VBD'),
#               174556),
#              (('VBD', 'RP'), 174557),
#              (('VBD', 'RP', 'NN', 'CC', 'NN', 'NNS'), 174558),
#              (('VBD', 'RP', 'NN', 'CC', 'NN', 'NNS', 'CC'), 174559),
#              (('CC', 'RB', 'VBD'), 174560),
#              (('VBD', 'DT', 'JJ', 'NNS'), 174561),
#              (('VBD', 'DT', 'JJ', 'NNS', 'IN'), 174562),
#              (('NN', 'VBN'), 174563),
#              (('VB', 'NNS'), 174564),
#              (('VBD',
#                'JJ',
#                'NN',
#                'NNS',
#                'IN',
#                'DT',
#                'VBN',
#                'NN',
#                'IN',
#                'DT',
#                'JJ',
#                'NN',
#                ',',
#                'VBD',
#                'RP',
#                'NN',
#                'CC',
#                'NN',
#                'NNS',
#                'CC',
#                'RB',
#                'VBD',
#                'DT',
#                'JJ',
#                'NNS',
#                'IN',
#                'DT',
#                'NN',
#                'VBN',
#                'TO',
#                'VB',
#                'NNS',
#                '.'),
#               174565),
#              (('VBD', '``', 'NNS'), 174566),
#              (('NNS', 'IN', 'JJ', 'NN', "''"), 174567),
#              (('NNS', 'IN', 'JJ', 'NN', "''", 'WDT', 'VBD'), 174568),
#              (('VBD', 'IN', 'NNS', 'IN', 'DT', 'NN', ','), 174569),
#              (('VBD', 'IN', 'NNS', 'IN', 'DT', 'NN', ',', 'RB', 'IN'), 174570),
#              (('IN', 'NN', 'NNS', 'VBD'), 174571),
#              (('VBD',
#                '``',
#                'NNS',
#                'IN',
#                'JJ',
#                'NN',
#                "''",
#                'WDT',
#                'VBD',
#                'IN',
#                'NNS',
#                'IN',
#                'DT',
#                'NN',
#                ',',
#                'RB',
#                'IN',
#                'NN',
#                'NNS',
#                'VBD',
#                'DT',
#                'NN',
#                '.'),
#               174572),
#              (('CC', 'NNS'), 174573),
#              (('IN', 'DT', 'IN', 'DT', 'NNS', 'CC', 'NNS', 'VBD'), 174574),
#              (('VBD', 'JJ', 'NNS'), 174575),
#              (('*',
#                '``',
#                'EX',
#                'VBZ',
#                'DT',
#                'NN',
#                'IN',
#                'DT',
#                'IN',
#                'DT',
#                'NNS',
#                'CC',
#                'NNS',
#                'VBD',
#                'JJ',
#                'NNS',
#                ',',
#                "''",
#                'VBD'),
#               174576),
#              (('NNP', ',', 'NN', 'NN'), 174577),
#              (('IN', 'JJ', 'NNS'), 174578),
#              (('NN', 'IN', 'JJ', 'NNS', 'IN'), 174579),
#              (('VBD',
#                'NNP',
#                'NNP',
#                ',',
#                'NN',
#                'NN',
#                'IN',
#                'JJ',
#                'NNS',
#                'IN',
#                'NNP',
#                'CC',
#                'NNP',
#                '.'),
#               174580),
#              (('*', '``', 'CC', 'PRP', 'VBP'), 174581),
#              (('VBP', 'TO'), 174582),
#              (('VB', 'IN'), 174583),
#              (('IN', 'DT', 'NNS', 'VBD'), 174584),
#              (('VBD', 'NN', 'CD', 'NNS', 'IN'), 174585),
#              (('VBP',
#                'TO',
#                'VB',
#                'IN',
#                'DT',
#                'NNS',
#                'VBD',
#                'NN',
#                'CD',
#                'NNS',
#                'IN',
#                '.'),
#               174586),
#              (('*', 'PRP', 'VBZ'), 174587),
#              (('IN', 'PRP$', 'NN', 'NN'), 174588),
#              (('NN', 'NN'), 174589),
#              (('VBZ', 'DT', 'NN', 'IN', 'PRP$', 'NN', 'NN', 'NN', '.'),
#               174590),
#              (('IN', 'JJ', 'JJ', 'NNS'), 174591),
#              (('*', 'NNS', 'IN', 'JJ', 'JJ', 'NNS', 'VBD'), 174592),
#              (('VBD', 'TO'), 174593),
#              (('VBD', 'TO', 'VB', ','), 174594),
#              (('VBD', 'TO', 'VB', ',', 'IN'), 174595),
#              (('IN', 'NN', 'NNS', 'VBP'), 174596),
#              (('VBD',
#                'TO',
#                'VB',
#                ',',
#                'IN',
#                'NNS',
#                'IN',
#                'NN',
#                'NNS',
#                'VBP',
#                'JJ',
#                'NNS',
#                'IN',
#                'NN',
#                'NNS',
#                '.'),
#               174597),
#              (('IN', 'DT', 'CD', 'JJ', 'NNS'), 174598),
#              (('*',
#                'DT',
#                'JJ',
#                'JJ',
#                'NN',
#                'NN',
#                'IN',
#                'DT',
#                'CD',
#                'JJ',
#                'NNS',
#                'VBN',
#                'IN',
#                'NNP',
#                'POS',
#                'NNP',
#                'NNP',
#                'NNP',
#                'VBD'),
#               174599),
#              (('IN', 'DT', 'NN', 'NN'), 174600),
#              (('VBD', 'DT', 'NN', 'IN', 'DT', 'NN', 'NN', 'TO'), 174601),
#              (('TO', 'CD', 'NN'), 174602),
#              (('VBD',
#                'DT',
#                'NN',
#                'IN',
#                'DT',
#                'NN',
#                'NN',
#                'TO',
#                'CD',
#                'NN',
#                'IN'),
#               174603),
#              (('IN', 'CD', 'NN'), 174604),
#              (('VBD',
#                'DT',
#                'NN',
#                'IN',
#                'DT',
#                'NN',
#                'NN',
#                'TO',
#                'CD',
#                'NN',
#                'IN',
#                'CD',
#                'NN',
#                'IN'),
#               174605),
#              (('NN', 'VBD'), 174606),
#              (('VBD', 'NNP'), 174607),
#              (('VBD',
#                'DT',
#                'NN',
#                'IN',
#                'DT',
#                'NN',
#                'NN',
#                'TO',
#                'CD',
#                'NN',
#                'IN',
#                'CD',
#                'NN',
#                'IN',
#                'DT',
#                'NN',
#                'VBD',
#                'NNP',
#                '.'),
#               174608),
#              (('*', 'NN', 'NNS', 'VBP'), 174609),
#              (('VBP', 'NN'), 174610),
#              (('NN', 'IN', 'NNS', 'CC'), 174611),
#              (('CC', 'IN'), 174612),
#              (('IN', 'DT', 'JJ', 'NN', 'VBZ'), 174613),
#              (('VBZ', 'IN'), 174614),
#              (('VBP',
#                'NN',
#                'IN',
#                'NNS',
#                'CC',
#                'IN',
#                'DT',
#                'JJ',
#                'NN',
#                'VBZ',
#                'IN',
#                'DT',
#                'NN',
#                '.'),
#               174615),
#              (('NNS', 'POS'), 174616),
#              (('IN', 'DT', 'NNS', 'POS', 'NNS'), 174617),
#              (('*', 'JJ', 'NN', 'IN', 'DT', 'NNS', 'POS', 'NNS', 'VBD'),
#               174618),
#              (('VBD', 'IN', 'DT', 'NN', 'TO'), 174619),
#              (('TO', 'CD', 'NNS'), 174620),
#              (('NNS', ','), 174621),
#              (('NNS', ',', 'DT', 'JJS'), 174622),
#              (('IN', 'JJ', 'NNP'), 174623),
#              (('NNS', ',', 'DT', 'JJS', 'IN', 'JJ', 'NNP', ','), 174624),
#              (('VBD',
#                'IN',
#                'DT',
#                'NN',
#                'TO',
#                'CD',
#                'NNS',
#                ',',
#                'DT',
#                'JJS',
#                'IN',
#                'JJ',
#                'NNP',
#                ',',
#                'VBG'),
#               174625),
#              (('TO', 'NNP'), 174626),
#              (('VBD',
#                'IN',
#                'DT',
#                'NN',
#                'TO',
#                'CD',
#                'NNS',
#                ',',
#                'DT',
#                'JJS',
#                'IN',
#                'JJ',
#                'NNP',
#                ',',
#                'VBG',
#                'TO',
#                'NNP',
#                'POS',
#                '.'),
#               174627),
#              (('*', 'JJR', 'NNS', 'VBP'), 174628),
#              (('VB', 'VBG', 'NN', 'NNS'), 174629),
#              (('VB', 'VBG', 'NN', 'NNS', 'IN'), 174630),
#              (('IN', 'PRP', 'VBP'), 174631),
#              (('VBP', 'NN', 'NNS', 'TO'), 174632),
#              (('VB', 'RB', 'JJR', 'NNS'), 174633),
#              (('VB', 'RB', 'JJR', 'NNS', 'IN'), 174634),
#              (('IN', 'DT', 'JJR', 'NN'), 174635),
#              (('VBP',
#                'VBN',
#                'TO',
#                'VB',
#                'VBG',
#                'NN',
#                'NNS',
#                'IN',
#                'PRP',
#                'VBP',
#                'NN',
#                'NNS',
#                'TO',
#                'VB',
#                'RB',
#                'JJR',
#                'NNS',
#                'IN',
#                'DT',
#                'JJR',
#                'NN',
#                '.'),
#               174636),
#              (('VBN', 'DT', 'NN'), 174637),
#              (('IN', 'VBG', 'NNS'), 174638),
#              (('VBN', 'DT', 'NN', 'IN', 'VBG', 'NNS', 'IN'), 174639),
#              (('IN', 'NN', 'NNS', 'MD'), 174640),
#              (('VB', 'JJR', 'NNS'), 174641),
#              (('VB', 'JJR', 'NNS', 'RB'), 174642),
#              (('VBP',
#                'VBN',
#                'DT',
#                'NN',
#                'IN',
#                'VBG',
#                'NNS',
#                'IN',
#                'NN',
#                'NNS',
#                'MD',
#                'VB',
#                'JJR',
#                'NNS',
#                'RB',
#                '.'),
#               174643),
#              (('NNS', 'JJ'), 174644),
#              (('JJ', 'RB', 'TO'), 174645),
#              (('TO', 'NNS'), 174646),
#              (('NN', 'IN', 'NNS', 'JJ', 'RB', 'TO', 'NNS', ','), 174647),
#              (('NN', 'IN', 'NNS', 'JJ', 'RB', 'TO', 'NNS', ',', 'VBN'),
#               174648),
#              (('VBN', 'IN', 'DT', 'TO'), 174649),
#              (('VB', 'DT', 'JJR', 'NN', 'IN'), 174650),
#              (('IN', 'DT', 'NNS', 'VBP'), 174651),
#              (('VBP', 'DT', 'NN'), 174652),
#              (('VBP', 'DT', 'NN', 'RB'), 174653),
#              (('NN',
#                'IN',
#                'NNS',
#                'JJ',
#                'RB',
#                'TO',
#                'NNS',
#                ',',
#                'VBN',
#                'IN',
#                'DT',
#                'TO',
#                'VB',
#                'DT',
#                'JJR',
#                'NN',
#                'IN',
#                'DT',
#                'NNS',
#                'VBP',
#                'DT',
#                'NN',
#                'RB',
#                ','),
#               174654),
#              (('*',
#                'DT',
#                'JJ',
#                'NN',
#                'IN',
#                'NNS',
#                'JJ',
#                'RB',
#                'TO',
#                'NNS',
#                ',',
#                'VBN',
#                'IN',
#                'DT',
#                'TO',
#                'VB',
#                'DT',
#                'JJR',
#                'NN',
#                'IN',
#                'DT',
#                'NNS',
#                'VBP',
#                'DT',
#                'NN',
#                'RB',
#                ',',
#                'VBD'),
#               174655),
#              (('NN', 'IN', 'DT', 'NN', ':', 'CD', 'NNS'), 174656),
#              (('VBD',
#                'DT',
#                'JJ',
#                'NN',
#                'IN',
#                'DT',
#                'NN',
#                ':',
#                'CD',
#                'NNS',
#                '.'),
#               174657),
#              (('NNP', ',', 'NN'), 174658),
#              (('IN', 'NNP', 'NNP', 'NNP'), 174659),
#              (('VBD',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'NN',
#                'IN',
#                'NNP',
#                'NNP',
#                'NNP',
#                ','),
#               174660),
#              (('*',
#                'RB',
#                ',',
#                'VBD',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'NN',
#                'IN',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'NNS',
#                '``',
#                'MD'),
#               174661),
#              (('VB', 'RP'), 174662),
#              (('VB', 'RP', 'RB'), 174663),
#              (('VB', 'RP', 'RB', 'IN'), 174664),
#              (('VB', 'RP', 'RB', 'IN', 'PRP', 'VBP', 'RP', "''"), 174665),
#              (('VB', 'RP', 'RB', 'IN', 'PRP', 'VBP', 'RP', "''", 'IN'),
#               174666),
#              (('IN', 'IN', 'JJ', 'NNS'), 174667),
#              (('IN', 'JJ', 'NN', 'NNS'), 174668),
#              (('MD',
#                'VB',
#                'RP',
#                'RB',
#                'IN',
#                'PRP',
#                'VBP',
#                'RP',
#                "''",
#                'IN',
#                'IN',
#                'JJ',
#                'NNS',
#                'IN',
#                'JJ',
#                'NN',
#                'NNS',
#                '.'),
#               174669),
#              (('IN', 'JJ', 'NNP', 'NNS'), 174670),
#              (('IN', 'NNP', 'POS', 'NN'), 174671),
#              (('*',
#                'DT',
#                'NN',
#                'IN',
#                'JJ',
#                'NNP',
#                'NNS',
#                'VBN',
#                'IN',
#                'NNP',
#                'POS',
#                'NN',
#                ',',
#                'IN',
#                'NN',
#                ',',
#                'VBD'),
#               174672),
#              (('VBD', 'TO', 'CD', 'NN', 'IN'), 174673),
#              (('VBD', 'TO', 'CD', 'NN', 'IN', 'CD', 'NN', '.'), 174674),
#              (('*', 'IN', 'JJ', 'NNS', 'IN', 'NNS', ',', 'NNS', 'VBP'),
#               174675),
#              (('VB', 'NN'), 174676),
#              (('VB', 'NN', 'IN'), 174677),
#              (('VBP', 'TO', 'VB', 'NN', 'IN', 'NN', 'NNS', '.'), 174678),
#              (('*', 'NNS', 'IN', 'DT', 'CD', 'JJ', 'NNS', 'VBD'), 174679),
#              (('IN', '$'), 174680),
#              (('$', 'CD'), 174681),
#              (('$', 'CD', 'CD'), 174682),
#              (('VBD', 'IN', '$', 'CD', 'CD', 'IN'), 174683),
#              (('IN', 'DT', 'JJS', 'NN'), 174684),
#              (('VBD', 'IN', '$', 'CD', 'CD', 'IN', 'DT', 'JJS', 'NN', ','),
#               174685),
#              (('VBD',
#                'IN',
#                '$',
#                'CD',
#                'CD',
#                'IN',
#                'DT',
#                'JJS',
#                'NN',
#                ',',
#                'TO'),
#               174686),
#              (('TO', '$'), 174687),
#              (('VBD',
#                'IN',
#                '$',
#                'CD',
#                'CD',
#                'IN',
#                'DT',
#                'JJS',
#                'NN',
#                ',',
#                'TO',
#                '$',
#                'CD',
#                'CD',
#                '.'),
#               174688),
#              (('*', 'RB', ',', 'NN', 'NNS', 'VBP'), 174689),
#              (('VBP', 'JJ', 'JJ', 'NNS'), 174690),
#              (('VBP', 'JJ', 'JJ', 'NNS', 'IN'), 174691),
#              (('VB', 'NNS', 'CC'), 174692),
#              (('CC', 'VB'), 174693),
#              (('IN', 'DT', 'JJS', 'NNS'), 174694),
#              (('VBP',
#                'JJ',
#                'JJ',
#                'NNS',
#                'IN',
#                'NN',
#                'NNS',
#                'MD',
#                'VB',
#                'NNS',
#                'CC',
#                'VB',
#                'IN',
#                'DT',
#                'JJS',
#                'NNS',
#                '.'),
#               174695),
#              (('*', 'DT', 'JJ', 'NN', 'NNS', 'VBP'), 174696),
#              (('VBP', 'RB'), 174697),
#              (('VBP', 'RB', 'VBG'), 174698),
#              (('RB', 'IN', 'CD'), 174699),
#              (('VBG', 'RB', 'IN', 'CD', 'NN'), 174700),
#              (('VBP', 'RB', 'VBG', 'RB', 'IN', 'CD', 'NN', '.'), 174701),
#              (('NNP', ',', 'DT', 'JJ', 'NN'), 174702),
#              (('NNP', ',', 'DT', 'JJ', 'NN', ','), 174703),
#              (('*', 'NNP', 'NNP', 'NNP', ',', 'DT', 'JJ', 'NN', ',', 'VBD'),
#               174704),
#              (('VBD', 'DT', 'JJ', 'NN', 'NN'), 174705),
#              (('VBD', 'DT', 'JJ', 'NN', 'NN', 'IN', 'CD', 'NN', 'IN'), 174706),
#              (('VBD',
#                'DT',
#                'JJ',
#                'NN',
#                'NN',
#                'IN',
#                'CD',
#                'NN',
#                'IN',
#                'DT',
#                'JJS',
#                'NN',
#                ','),
#               174707),
#              (('VBD',
#                'DT',
#                'JJ',
#                'NN',
#                'NN',
#                'IN',
#                'CD',
#                'NN',
#                'IN',
#                'DT',
#                'JJS',
#                'NN',
#                ',',
#                'RB'),
#               174708),
#              (('IN', 'CD', 'NN', 'DT', 'NN', 'JJR'), 174709),
#              (('VBD',
#                'DT',
#                'JJ',
#                'NN',
#                'NN',
#                'IN',
#                'CD',
#                'NN',
#                'IN',
#                'DT',
#                'JJS',
#                'NN',
#                ',',
#                'RB',
#                'IN',
#                'CD',
#                'NN',
#                'DT',
#                'NN',
#                'JJR',
#                '.'),
#               174710),
#              (('VBZ', 'RB', 'IN'), 174711),
#              (('VBZ', 'RB', 'IN', 'JJ', 'NNS', 'RB'), 174712),
#              (('VBZ', 'RB', 'IN', 'JJ', 'NNS', 'RB', 'CC'), 174713),
#              (('CC', 'VBZ'), 174714),
#              (('VBZ', 'RB', 'VBG'), 174715),
#              (('VBG', 'NN', 'NNS'), 174716),
#              (('VBG', 'NN', 'NNS', ','), 174717),
#              (('VBG', 'NN', 'NNS', ',', 'WDT', 'VBZ'), 174718),
#              (('VBZ', 'PRP$', 'NN'), 174719),
#              (('VBZ',
#                'RB',
#                'IN',
#                'JJ',
#                'NNS',
#                'RB',
#                'CC',
#                'VBZ',
#                'RB',
#                'VBG',
#                'NN',
#                'NNS',
#                ',',
#                'WDT',
#                'VBZ',
#                'PRP$',
#                'NN',
#                '.'),
#               174720),
#              (('IN', 'DT', 'CD', 'NNS'), 174721),
#              (('*',
#                'DT',
#                'JJ',
#                'JJ',
#                'JJ',
#                'NN',
#                'IN',
#                'DT',
#                'CD',
#                'NNS',
#                'VBD'),
#               174722),
#              (('VBD', 'CD', 'NN'), 174723),
#              (('VBD', 'CD', 'NN', ','), 174724),
#              (('VBD', 'CD', 'NN', ',', 'RB'), 174725),
#              (('VBD', 'CD', 'NN', ',', 'RB', 'IN', 'CD', 'NN', '.'), 174726),
#              (('*', 'DT', 'JJ', 'JJ', 'NN', 'VBD'), 174727),
#              (('TO', 'DT', 'JJ', 'CD', 'NN'), 174728),
#              (('VBD', 'TO', 'DT', 'JJ', 'CD', 'NN', 'IN'), 174729),
#              (('VBD', 'TO', 'DT', 'JJ', 'CD', 'NN', 'IN', 'CD', 'NN', ':'),
#               174730),
#              (('VBD',
#                'TO',
#                'DT',
#                'JJ',
#                'CD',
#                'NN',
#                'IN',
#                'CD',
#                'NN',
#                ':',
#                'DT',
#                'JJ',
#                'NN',
#                'NN',
#                'VBD'),
#               174731),
#              (('VBD',
#                'TO',
#                'DT',
#                'JJ',
# ...
#                'JJ',
#                'NNS',
#                'RB',
#                'VBN',
#                'NNP',
#                'NNP',
#                'NNP',
#                '.'),
#               175205),
#              (('NN', 'WP', 'VBZ'), 175206),
#              (('VBZ', 'NNP'), 175207),
#              (('*',
#                'DT',
#                'NN',
#                'WP',
#                'VBZ',
#                'NNP',
#                'IN',
#                'NNP',
#                'NNP',
#                ',',
#                'IN',
#                'PRP',
#                'VBZ',
#                'IN',
#                'NN',
#                'NNS',
#                'PRP$',
#                'NNS',
#                'MD',
#                'VB',
#                'IN',
#                'DT',
#                'JJS',
#                'IN',
#                'DT',
#                'NN',
#                ',',
#                'PRP',
#                'VBD'),
#               175208),
#              (('*', '``', 'DT', 'VBZ'), 175209),
#              (('VBZ', 'NN', ':'), 175210),
#              (('VBD', 'RB', 'DT', 'CD'), 175211),
#              (('NNS', "''"), 175212),
#              (('NNS', "''", 'WDT', 'VBD'), 175213),
#              (('TO', 'DT', 'NN', 'POS', 'NN'), 175214),
#              (('*',
#                'PRP',
#                'VBD',
#                'RB',
#                'DT',
#                'CD',
#                'IN',
#                'DT',
#                'NN',
#                'NNS',
#                "''",
#                'WDT',
#                'VBD',
#                'TO',
#                'DT',
#                'NN',
#                'POS',
#                'NN',
#                'TO',
#                'VB',
#                'IN',
#                'DT',
#                'NN',
#                ',',
#                'PRP',
#                'VBD'),
#               175215),
#              (('TO', 'DT', 'JJ', 'NN', 'POS', 'NN', 'NNS'), 175216),
#              (('*',
#                'NNP',
#                'NNP',
#                'NNP',
#                'IN',
#                'NNP',
#                'NNP',
#                ',',
#                'DT',
#                'JJ',
#                'NN',
#                'TO',
#                'DT',
#                'JJ',
#                'NN',
#                'POS',
#                'NN',
#                'NNS',
#                ',',
#                'VBD'),
#               175217),
#              (('VBD', 'DT', 'NN', 'IN', 'NNP', 'NNP', 'NNP', 'MD'), 175218),
#              (('VB', 'RP', 'DT', 'NN', 'NN'), 175219),
#              (('VBD',
#                'DT',
#                'NN',
#                'IN',
#                'NNP',
#                'NNP',
#                'NNP',
#                'MD',
#                'VB',
#                'RP',
#                'DT',
#                'NN',
#                'NN',
#                '.'),
#               175220),
#              (('IN', 'NNP', 'NNP', 'VBD'), 175221),
#              (('VBD', 'JJR', 'NN', 'NNS'), 175222),
#              (('NNS', ':', 'CD', 'NN'), 175223),
#              (('NN', 'IN', 'CD', 'NNS', 'IN'), 175224),
#              (('CD', 'NN'), 175225),
#              (('IN', 'IN', 'CD', 'NN', 'NNS'), 175226),
#              (('IN', 'DT', 'JJ', 'CD', 'JJ', 'NNS'), 175227),
#              (('NN',
#                'IN',
#                'CD',
#                'NNS',
#                'IN',
#                'IN',
#                'CD',
#                'NN',
#                'NNS',
#                'VBN',
#                'IN',
#                'DT',
#                'JJ',
#                'CD',
#                'JJ',
#                'NNS',
#                ':'),
#               175228),
#              (('*',
#                'DT',
#                'NN',
#                'IN',
#                'NNP',
#                'NNP',
#                'VBD',
#                'JJR',
#                'NN',
#                'NNS',
#                ':',
#                'CD',
#                'NN',
#                'IN',
#                'CD',
#                'NNS',
#                'IN',
#                'IN',
#                'CD',
#                'NN',
#                'NNS',
#                'VBN',
#                'IN',
#                'DT',
#                'JJ',
#                'CD',
#                'JJ',
#                'NNS',
#                ':',
#                'IN',
#                'NNS',
#                'IN',
#                'NN',
#                'NNS',
#                ',',
#                'NNP',
#                'NNP',
#                'VBD'),
#               175229),
#              (('VBZ', 'RBR', 'VBN'), 175230),
#              (('*',
#                '``',
#                'RB',
#                'DT',
#                'NN',
#                'VBZ',
#                'RBR',
#                'VBN',
#                ',',
#                "''",
#                'PRP',
#                'VBD'),
#               175231),
#              (('*', 'RB', ',', 'DT', 'NNP', 'NNP', 'NNP', 'NNP', 'VBD'),
#               175232),
#              (('VBD', 'RP', 'IN'), 175233),
#              (('VBD', 'RP', 'IN', 'RB', 'DT', 'NN'), 175234),
#              (('NN', 'IN', 'NNP', 'VBG'), 175235),
#              (('VBD',
#                'RP',
#                'IN',
#                'RB',
#                'DT',
#                'NN',
#                'IN',
#                'NNP',
#                'VBG',
#                'NN',
#                'IN',
#                'PRP$',
#                'JJ',
#                'NN',
#                'IN',
#                'NNP',
#                'IN',
#                'NNP',
#                'NNP',
#                '.'),
#               175236),
#              (('VB', 'PRP$', 'NN'), 175237),
#              (('MD', 'VB', 'PRP$', 'NN', 'CC'), 175238),
#              (('CC', 'RB', 'VBZ'), 175239),
#              (('IN', 'DT', 'NNP'), 175240),
#              (('MD',
#                'VB',
#                'PRP$',
#                'NN',
#                'CC',
#                'RB',
#                'VBZ',
#                'IN',
#                'DT',
#                'VBN',
#                'NN',
#                'IN',
#                'DT',
#                'NNP',
#                'IN'),
#               175241),
#              (('IN', 'IN', 'PRP', 'MD'), 175242),
#              (('VB', 'DT', 'NN', 'IN', 'JJ', 'NN', 'IN'), 175243),
#              (('IN', 'PRP$', 'NN', 'VBZ'), 175244),
#              (('VBD',
#                'PRP',
#                'MD',
#                'VB',
#                'PRP$',
#                'NN',
#                'CC',
#                'RB',
#                'VBZ',
#                'IN',
#                'DT',
#                'VBN',
#                'NN',
#                'IN',
#                'DT',
#                'NNP',
#                'IN',
#                'IN',
#                'PRP',
#                'MD',
#                'VB',
#                'DT',
#                'NN',
#                'IN',
#                'JJ',
#                'NN',
#                'IN',
#                'PRP$',
#                'NN',
#                'VBZ',
#                'DT',
#                'NN',
#                'VBD',
#                'IN',
#                'DT',
#                'NN',
#                'NN',
#                '.'),
#               175245),
#              (('*', 'NNP', 'IN', 'NNP', 'NNP', 'NNS', 'VBD'), 175246),
#              (('VBD', 'NN', 'IN'), 175247),
#              (('$', 'CD', ','), 175248),
#              (('$', 'CD', ',', 'IN'), 175249),
#              (('$', 'CD', ',', 'IN', 'CD', 'NNS', ','), 175250),
#              (('VBD',
#                'NN',
#                'IN',
#                '$',
#                'CD',
#                ',',
#                'IN',
#                'CD',
#                'NNS',
#                ',',
#                'IN'),
#               175251),
#              (('IN', 'NNP', 'NNP', 'NNP', 'NNP', 'JJ', 'NN'), 175252),
#              (('VBD',
#                'NN',
#                'IN',
#                '$',
#                'CD',
#                ',',
#                'IN',
#                'CD',
#                'NNS',
#                ',',
#                'IN',
#                'NNP',
#                'NNP',
#                'NNP',
#                'NNP',
#                'JJ',
#                'NN',
#                '.'),
#               175253),
#              (('CC', 'NN', 'VBG', 'NN'), 175254),
#              (('NN', 'CC', 'NN', 'VBG', 'NN', 'IN'), 175255),
#              (('IN', 'NNPS', '``', 'NNP', "''", 'NNP', 'NNP'), 175256),
#              (('NNP',
#                ',',
#                'CD',
#                'NNS',
#                'JJ',
#                'CC',
#                'JJ',
#                'NN',
#                'CC',
#                'NN',
#                'VBG',
#                'NN',
#                'IN',
#                'NNPS',
#                '``',
#                'NNP',
#                "''",
#                'NNP',
#                'NNP',
#                ','),
#               175257),
#              (('NNP',
#                ',',
#                'CD',
#                'NNS',
#                'JJ',
#                'CC',
#                'JJ',
#                'NN',
#                'CC',
#                'NN',
#                'VBG',
#                'NN',
#                'IN',
#                'NNPS',
#                '``',
#                'NNP',
#                "''",
#                'NNP',
#                'NNP',
#                ',',
#                'CC'),
#               175258),
#              (('CC', 'NNP', 'NNP', 'NNP'), 175259),
#              (('NNP', ',', 'CD'), 175260),
#              (('NNP', ',', 'CD', ','), 175261),
#              (('NNP', ',', 'CD', ',', 'NN'), 175262),
#              (('NNP',
#                ',',
#                'CD',
#                'NNS',
#                'JJ',
#                'CC',
#                'JJ',
#                'NN',
#                'CC',
#                'NN',
#                'VBG',
#                'NN',
#                'IN',
#                'NNPS',
#                '``',
#                'NNP',
#                "''",
#                'NNP',
#                'NNP',
#                ',',
#                'CC',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'CD',
#                ',',
#                'NN',
#                'IN',
#                'NNP',
#                'NNP',
#                'NNP',
#                ','),
#               175263),
#              (('*',
#                'NNP',
#                'NNP',
#                ',',
#                'CD',
#                'NNS',
#                'JJ',
#                'CC',
#                'JJ',
#                'NN',
#                'CC',
#                'NN',
#                'VBG',
#                'NN',
#                'IN',
#                'NNPS',
#                '``',
#                'NNP',
#                "''",
#                'NNP',
#                'NNP',
#                ',',
#                'CC',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'CD',
#                ',',
#                'NN',
#                'IN',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'VBD'),
#               175264),
#              (('IN', 'DT', 'NN', 'NNS', 'CC', 'NNS', 'NN', 'NN'), 175265),
#              (('VBD',
#                'VBN',
#                'NNS',
#                'IN',
#                'DT',
#                'NN',
#                'NNS',
#                'CC',
#                'NNS',
#                'NN',
#                'NN',
#                '.'),
#               175266),
#              (('VBP', 'NNP', 'NNP', 'NNP'), 175267),
#              (('NNP', ',', 'VBN', 'NNP', 'NNP', 'JJ', 'NN', 'NN'), 175268),
#              (('NNP', ',', 'VBN', 'NNP', 'NNP', 'JJ', 'NN', 'NN', ','),
#               175269),
#              (('NNP', ',', 'VBN', 'NNP', 'NNP', 'JJ', 'NN', 'NN', ',', 'CC'),
#               175270),
#              (('NNP', ',', 'NNP', 'NNP', 'NN'), 175271),
#              (('NNP',
#                ',',
#                'VBN',
#                'NNP',
#                'NNP',
#                'JJ',
#                'NN',
#                'NN',
#                ',',
#                'CC',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'NNP',
#                'NNP',
#                'NN',
#                ','),
#               175272),
#              (('VBP',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'VBN',
#                'NNP',
#                'NNP',
#                'JJ',
#                'NN',
#                'NN',
#                ',',
#                'CC',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'NNP',
#                'NNP',
#                'NN',
#                ',',
#                'IN'),
#               175273),
#              (('VBP',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'VBN',
#                'NNP',
#                'NNP',
#                'JJ',
#                'NN',
#                'NN',
#                ',',
#                'CC',
#                'NNP',
#                'NNP',
#                'NNP',
#                ',',
#                'NNP',
#                'NNP',
#                'NN',
#                ',',
#                'IN',
#                'DT',
#                'JJ',
#                'NN',
#                '.'),
#               175274),
#              (('VB', 'IN', '$'), 175275),
#              (('VB', 'IN', '$', 'CD', 'CD', 'TO'), 175276),
#              (('TO', 'PRP$', 'JJ', 'CC', 'JJ', 'NNS'), 175277),
#              (('VB',
#                'IN',
#                '$',
#                'CD',
#                'CD',
#                'TO',
#                'PRP$',
#                'JJ',
#                'CC',
#                'JJ',
#                'NNS',
#                'IN'),
#               175278),
#              (('VBD',
#                'VBN',
#                'TO',
#                'VB',
#                'IN',
#                '$',
#                'CD',
#                'CD',
#                'TO',
#                'PRP$',
#                'JJ',
#                'CC',
#                'JJ',
#                'NNS',
#                'IN',
#                'JJ',
#                'NNS',
#                'VBN',
#                'IN',
#                'NN',
#                'NNS',
#                'IN',
#                'DT',
#                'JJ',
#                'NN',
#                'NN',
#                '.'),
#               175279),
#              (('*', 'DT', 'NN', 'VBD'), 175280),
#              (('VBD', 'IN', '$', 'CD', 'CD', 'JJR'), 175281),
#              (('IN', 'RB', 'VBN'), 175282),
#              (('VBD',
#                'IN',
#                '$',
#                'CD',
#                'CD',
#                'JJR',
#                'IN',
#                'RB',
#                'VBN',
#                'IN',
#                'DT',
#                'NNP',
#                'NNP',
#                'NNP',
#                'CC'),
#               175283),
#              (('CC', 'NN', 'NNS', 'VBD'), 175284),
#              (('JJS', 'RB', 'VBN'), 175285),
#              (('IN', 'DT', 'NN', 'CC', 'JJ', 'NN'), 175286),
#              (('VBD',
#                'IN',
#                '$',
#                'CD',
#                'CD',
#                'JJR',
#                'IN',
#                'RB',
#                'VBN',
#                'IN',
#                'DT',
#                'NNP',
#                'NNP',
#                'NNP',
#                'CC',
#                'NN',
#                'NNS',
#                'VBD',
#                'PRP',
#                'MD',
#                'VB',
#                'DT',
#                'JJS',
#                'RB',
#                'VBN',
#                'IN',
#                'DT',
#                'NN',
#                'CC',
#                'JJ',
#                'NN',
#                '.'),
#               175287),
#              (('*', 'NN', 'NN', 'NNP', 'NNP', 'NNP', 'VBD'), 175288),
#              (('VBD', 'NNP', 'TO'), 175289),
#              (('VB', 'JJ', 'NNS'), 175290),
#              (('$', 'CD', 'TO'), 175291),
#              (('$', 'CD', 'TO', '$'), 175292),
#              (('$', 'CD', 'TO', '$', 'CD'), 175293),
#              (('$', 'CD', 'TO', '$', 'CD', 'DT'), 175294),
#              (('VB',
#                'JJ',
#                'NNS',
#                'IN',
#                'IN',
#                '$',
#                'CD',
#                'TO',
#                '$',
#                'CD',
#                'DT',
#                'TO'),
#               175295),
#              ...])

# %%
print(head, child, a)
# Out:
# DepSample(idx=2, token='Vinken', pos='NNP', head=8) DepSample(idx=6, token='old', pos='JJ', head=2) 187029
