# %%
import time
import os
import pickle
import numpy as np
from collections import OrderedDict
from collections import namedtuple
from random import shuffle
import copy
from itertools import combinations, combinations_with_replacement
from utils.utils import ROOT, dep_sample_generator
from typing import List, Dict

# %%
def generate_features_dict(path_to_file, sample2features, start_idx, feature_threshold=0, save_to_file=False,
                           features_name=''):
    """
    This function generates a features dictionary, such that for every features, an index is given starting from start
    the given start_idx.
    The following features are generated for a given dataset:
    byt the given sample2features which is a lambda exprestion to extract a feature from a sample
    you can think of sample2features as a template
    :param: path_to_file: path to location of the dataset (str)
    :param: feature_threshold: if to consider a feature with word that appears less than that in the dataset (int)
    :param: save_to_file: whether or not to save the dictionary on the disk (bool)
    :param: word_hist: dictionary of words histogram in the dataset (dict)
    :return: hw_hp_feat_dict: dictionary feature->index (dict)
    """

    samp_gen = dep_sample_generator(path_to_file)
    hw_hp_feat_dict = OrderedDict()
    features_hist = OrderedDict()

    for s_i, sample in enumerate(samp_gen):
        for s in sample:
            # ignore ROOT
            if s.token == ROOT:
                continue
            

            feats = sample2features(sample, s)
            for feat in feats:
                features_hist[feat] = features_hist.get(feat, 0) + 1

    current_idx = start_idx
    for k, v in features_hist.items():
        if v > feature_threshold:
            hw_hp_feat_dict[k] = current_idx
            current_idx += 1

#     print("total {:} features: ".format(features_name), current_idx)
    hw_hp_feat_dict = OrderedDict(sorted(hw_hp_feat_dict.items(), key=lambda t: t[1]))
    if save_to_file:
        path = path_to_file + features_name + '.dict'
        with open(path, 'wb') as fp:
            pickle.dump(hw_hp_feat_dict, fp)
        print("saved {:} features dictionary @ ".format(features_name), path)
    return hw_hp_feat_dict

# %%
def generate_inbetween_features(sample, s):
    """
    This function generates the features:
    (head word, b word, child word) for h.idx < b.idx < c.idx
    :param: sample (list of DepSamples)
    :param: s (DepSample)
    :return: inbetween_features (list of tuples)
    """
    start_idx = min(s.idx, sample[s.head].idx)
    end_idx = max(s.idx, sample[s.head].idx)
    inbetween_features = []
    for i in range(start_idx + 1, end_idx):
        inbetween_features.append((sample[s.head].pos, sample[i].pos, s.pos))
    return inbetween_features

# %%
generate_inbetween_features(sample, sample[6])
# Out:
# [('NNP', ',', 'JJ'), ('NNP', 'CD', 'JJ'), ('NNP', 'NNS', 'JJ')]

# %%
def generate_features_dicts(path_to_file: str, save_to_file: bool =False, minimal: bool=False
                            , use_mcdonald: bool=False)->Dict[str, dict]:
    """
    given a training file we return a dictionary of dictionaries
    where key is feature type name, and value is a dictionary of that feature generated by 'generate_features_dict'
    according to feature templates required by hw2 pg 2, those templates are:
    head word _ head pos
    head word
    head pos
    child word _ child pos
    child word
    child pos
    h_pos c_word c_pos

    if not minimal we add:
        h_word h_pos c_word c_pos
        h_word c_word c_pos
        h_word h_pos c_word
        h_word c_word
        
    if use mcdonald:
        distance(head,child)
        # is head to the right or left of the child:
        1 if head.idx < child.idx
        # in-between POS features:
        (h_pos, b_pos, c_pos)
        # surrounding word POS features:
        (h_pos, h+1_pos, c-1_pos, c_pos)
        (h-1_pos, h_pos, c-1_pos, c_pos)
        (h_pos, h+1_pos, c_pos, c+1_pos)
        (h-1_pos, h_pos, c_pos, c+1_pos)
    :param path_to_file: training file to extract features from
    :param save_to_file: if to save the dictionary
    :param minimal: if to add the extra features as described
    :return: dictionary described above
    """

    feature_types = {'head word _ head pos': (lambda sample, s: [(sample[s.head].token, sample[s.head].pos)], 0),
                     'head word': (lambda sample, s: [(sample[s.head].token)], 0),
                     'head pos': (lambda sample, s: [(sample[s.head].pos)], 0),
                     'child word _ child pos': (lambda sample, s: [(s.token, s.pos)], 0),
                     'child word': (lambda sample, s: [(s.token)], 0),
                     'child pos': (lambda sample, s: [(s.pos)], 0),
                     'h_pos c_word c_pos': (lambda sample, s: [(sample[s.head].pos, s.token, s.pos)], 0),
                     'h_word h_pos c_pos': (lambda sample, s: [(sample[s.head].token, sample[s.head].pos, s.pos)], 0),
                     'h_pos c_pos': (lambda sample, s: [(sample[s.head].pos, s.pos)], 0),
                     }

    if not minimal:

        feature_types['h_word h_pos c_word c_pos'] = (lambda sample, s:
                                                      [(sample[s.head].token, sample[s.head].pos, s.token, s.pos)], 0)

        feature_types['h_word c_word c_pos'] = (lambda sample, s:
                                                [(sample[s.head].token, s.token, s.pos)], 0)

        feature_types['h_word h_pos c_word'] = (lambda sample, s:
                                                [(sample[s.head].token, sample[s.head].pos, s.token)], 0)

        feature_types['h_word c_word'] = (lambda sample, s:
                                          [(sample[s.head].token, s.token)], 0)
        
    if use_mcdonald:
        # distance + is head to the right of child? (-) if child > head, (+) else
        # maybe we can add the distance to the unigrams?
        feature_types['h_word c_word dist'] = (lambda sample, s:
                                                      [(sample[s.head].token, s.token, sample[s.head].idx - s.idx)], 0)
        # in-between POS features:
        feature_types['h_c_pos_seq'] = (lambda sample, s:
                                                      [tuple(l.pos for l in sample[sample[s.head].idx : s.idx + 1])], 0)
        feature_types['h_b_c_pos'] = (lambda sample, s: generate_inbetween_features(sample, s), 0)
        # surrounding word POS features
        feature_types['h_pos h_next_pos c_prev_pos c_pos'] = (lambda sample, s:
                                                              [(sample[s.head].pos,
                                                                sample[min(s.head + 1, sample[-1].idx)].pos,
                                                                sample[max(s.idx - 1, 0)].pos,
                                                                s.pos)], 0)
        
        feature_types['h_prev_pos h_pos c_prev_pos c_pos'] = (lambda sample, s:
                                                              [(sample[max(s.head - 1, 0)].pos,
                                                                sample[s.head].pos,
                                                                sample[max(s.idx - 1, 0)].pos,
                                                                s.pos)], 0)
        
        feature_types['h_pos h_next_pos c_pos c_next_pos'] = (lambda sample, s:
                                                              [(sample[s.head].pos,
                                                                sample[min(s.head + 1, sample[-1].idx)].pos,
                                                                s.pos,
                                                                sample[min(s.idx + 1, sample[-1].idx)].pos)], 0)
        
        feature_types['h_prev_pos h_pos c_pos c_next_pos'] = (lambda sample, s:
                                                              [(sample[max(s.head - 1, 0)].pos,
                                                                sample[s.head].pos,
                                                                s.pos,
                                                                sample[min(s.idx + 1, sample[-1].idx)].pos)], 0)
    features_dicts = {}
    current_num_features = 0
    for feature_type_name, (feature_template, feature_threshold) in feature_types.items():

        features_dicts[feature_type_name] = generate_features_dict(path_to_file,
                                                                   feature_template,
                                                                   start_idx=current_num_features,
                                                                   feature_threshold=feature_threshold,
                                                                   save_to_file=False,
                                                                   features_name=feature_type_name)

        num_features = len(features_dicts[feature_type_name])
        current_num_features += num_features

        print('generated {:} features , num features: {:}, total num features: {:}'.format(feature_type_name,
                                                                                         num_features,
                                                                                         current_num_features))

    return features_dicts

# %%
dictionaries = generate_features_dicts('./data/train.labeled.train.labeled', use_mcdonald=True)
# Out:
# generated head word _ head pos features , num features: 8595, total num features: 8595
# generated head word features , num features: 7669, total num features: 16264
# generated head pos features , num features: 36, total num features: 16300
# generated child word _ child pos features , num features: 13641, total num features: 29941
# generated child word features , num features: 12218, total num features: 42159
# generated child pos features , num features: 45, total num features: 42204
# generated h_pos c_word c_pos features , num features: 26559, total num features: 68763
# generated h_word h_pos c_pos features , num features: 28735, total num features: 97498
# generated h_pos c_pos features , num features: 711, total num features: 98209
# generated h_word h_pos c_word c_pos features , num features: 58981, total num features: 157190
# generated h_word c_word c_pos features , num features: 58363, total num features: 215553
# generated h_word h_pos c_word features , num features: 58614, total num features: 274167
# generated h_word c_word features , num features: 57981, total num features: 332148
# generated h_word c_word dist features , num features: 68440, total num features: 400588
# generated h_c_pos_seq features , num features: 17414, total num features: 418002
# generated h_b_c_pos features , num features: 8073, total num features: 426075
# generated h_pos h_next_pos c_prev_pos c_pos features , num features: 15998, total num features: 442073
# generated h_prev_pos h_pos c_prev_pos c_pos features , num features: 15127, total num features: 457200
# generated h_pos h_next_pos c_pos c_next_pos features , num features: 16465, total num features: 473665
# generated h_prev_pos h_pos c_pos c_next_pos features , num features: 16662, total num features: 490327

# %%
dictionaries.keys()
# Out:
# dict_keys(['head word _ head pos', 'head word', 'head pos', 'child word _ child pos', 'child word', 'child pos', 'h_pos c_word c_pos', 'h_word h_pos c_pos', 'h_pos c_pos', 'h_word h_pos c_word c_pos', 'h_word c_word c_pos', 'h_word h_pos c_word', 'h_word c_word', 'h_word c_word dist', 'h_c_pos_seq', 'h_b_c_pos', 'h_pos h_next_pos c_prev_pos c_pos', 'h_prev_pos h_pos c_prev_pos c_pos', 'h_pos h_next_pos c_pos c_next_pos', 'h_prev_pos h_pos c_pos c_next_pos'])

# %%
sample = next(dep_sample_generator('./data/train.labeled.train.labeled'))
sample
child = sample[6]
head = sample[child.head]

# %%
dict2check = 'child word _ child pos'

# %%
a = dictionaries['h_word c_word'].get((head.token, child.token))
a
# Out:
# 187029

# %%
dictionaries['h_b_c_pos']
# Out:
# OrderedDict([(('MD', ',', 'NNP'), 418002),
#              (('MD', 'CD', 'NNP'), 418003),
#              (('MD', 'NNS', 'NNP'), 418004),
#              (('MD', 'JJ', 'NNP'), 418005),
#              (('NNP', ',', 'JJ'), 418006),
#              (('NNP', 'CD', 'JJ'), 418007),
#              (('NNP', 'NNS', 'JJ'), 418008),
#              (('NNP', ',', ','), 418009),
#              (('NNP', 'CD', ','), 418010),
#              (('NNP', 'NNS', ','), 418011),
#              (('NNP', 'JJ', ','), 418012),
#              (('*', 'NNP', 'MD'), 418013),
#              (('*', ',', 'MD'), 418014),
#              (('*', 'CD', 'MD'), 418015),
#              (('*', 'NNS', 'MD'), 418016),
#              (('*', 'JJ', 'MD'), 418017),
#              (('VB', 'DT', 'NN'), 418018),
#              (('VB', 'DT', 'IN'), 418019),
#              (('VB', 'NN', 'IN'), 418020),
#              (('NN', 'JJ', 'DT'), 418021),
#              (('IN', 'DT', 'NN'), 418022),
#              (('IN', 'JJ', 'NN'), 418023),
#              (('VB', 'DT', 'NNP'), 418024),
#              (('VB', 'NN', 'NNP'), 418025),
#              (('VB', 'IN', 'NNP'), 418026),
#              (('VB', 'JJ', 'NNP'), 418027),
#              (('MD', 'VB', '.'), 418028),
#              (('MD', 'DT', '.'), 418029),
#              (('MD', 'NN', '.'), 418030),
#              (('MD', 'IN', '.'), 418031),
#              (('MD', 'JJ', '.'), 418032),
#              (('MD', 'NNP', '.'), 418033),
#              (('MD', 'CD', '.'), 418034),
#              (('*', 'NNP', 'VBZ'), 418035),
#              (('IN', 'NNP', 'NNP'), 418036),
#              (('NN', 'NNP', 'DT'), 418037),
#              (('NN', 'VBG', 'DT'), 418038),
#              (('NN', 'VBG', 'NNP'), 418039),
#              (('NNP', ',', 'NN'), 418040),
#              (('NNP', 'DT', 'NN'), 418041),
#              (('NNP', 'NNP', 'NN'), 418042),
#              (('NNP', 'VBG', 'NN'), 418043),
#              (('VBZ', 'NN', '.'), 418044),
#              (('VBZ', 'IN', '.'), 418045),
#              (('VBZ', 'NNP', '.'), 418046),
#              (('VBZ', ',', '.'), 418047),
#              (('VBZ', 'DT', '.'), 418048),
#              (('VBZ', 'VBG', '.'), 418049),
#              (('VBD', ',', 'NNP'), 418050),
#              (('VBD', 'CD', 'NNP'), 418051),
#              (('VBD', 'NNS', 'NNP'), 418052),
#              (('VBD', 'JJ', 'NNP'), 418053),
#              (('VBD', 'CC', 'NNP'), 418054),
#              (('VBD', 'NN', 'NNP'), 418055),
#              (('VBD', 'IN', 'NNP'), 418056),
#              (('VBD', 'NNP', 'NNP'), 418057),
#              (('CC', 'JJ', 'NN'), 418058),
#              (('NNP', 'NNP', 'NNP'), 418059),
#              (('NNP', 'CC', ','), 418060),
#              (('NNP', 'NN', ','), 418061),
#              (('NNP', 'IN', ','), 418062),
#              (('NNP', 'NNP', ','), 418063),
#              (('*', 'NNP', 'VBD'), 418064),
#              (('*', ',', 'VBD'), 418065),
#              (('*', 'CD', 'VBD'), 418066),
#              (('*', 'NNS', 'VBD'), 418067),
#              (('*', 'JJ', 'VBD'), 418068),
#              (('*', 'CC', 'VBD'), 418069),
#              (('*', 'NN', 'VBD'), 418070),
#              (('*', 'IN', 'VBD'), 418071),
#              (('VBN', 'DT', 'NN'), 418072),
#              (('VBN', 'JJ', 'NN'), 418073),
#              (('NN', 'JJ', 'JJ'), 418074),
#              (('VBD', 'VBN', '.'), 418075),
#              (('VBD', 'DT', '.'), 418076),
#              (('VBD', 'JJ', '.'), 418077),
#              (('VBD', 'NN', '.'), 418078),
#              (('VBD', 'IN', '.'), 418079),
#              (('VBZ', 'IN', 'NN'), 418080),
#              (('VBZ', 'NN', 'NN'), 418081),
#              (('VBZ', 'RB', 'NN'), 418082),
#              (('VBZ', 'VBN', 'NN'), 418083),
#              (('VBZ', 'TO', 'NN'), 418084),
#              (('VBZ', 'VB', 'NN'), 418085),
#              (('VBZ', 'NNP', 'NN'), 418086),
#              (('VBZ', 'NNS', 'NN'), 418087),
#              (('NN', 'IN', 'VBN'), 418088),
#              (('NN', 'NN', 'VBN'), 418089),
#              (('NN', 'RB', 'VBN'), 418090),
#              (('NNS', 'NN', 'NNP'), 418091),
#              (('VB', 'NNP', 'NNS'), 418092),
#              (('VB', 'NN', 'NNS'), 418093),
#              (('VBD', 'VBN', 'VBZ'), 418094),
#              (('VBD', 'DT', 'VBZ'), 418095),
#              (('VBD', 'JJ', 'VBZ'), 418096),
#              (('VBD', 'NN', 'VBZ'), 418097),
#              (('VBD', 'IN', 'VBZ'), 418098),
#              (('VBD', 'NNS', 'VBZ'), 418099),
#              (('VBD', 'TO', 'VBZ'), 418100),
#              (('VBD', 'PRP', 'VBZ'), 418101),
#              (('VBD', 'RBR', 'VBZ'), 418102),
#              (('VBD', 'CD', 'VBZ'), 418103),
#              (('VBD', ',', 'VBZ'), 418104),
#              (('IN', 'NN', 'NNS'), 418105),
#              (('NN', 'IN', 'IN'), 418106),
#              (('NN', 'NN', 'IN'), 418107),
#              (('NN', 'NNS', 'IN'), 418108),
#              (('CD', 'IN', 'RBR'), 418109),
#              (('VBN', 'TO', 'IN'), 418110),
#              (('VBN', 'PRP', 'IN'), 418111),
#              (('VBN', 'RBR', 'IN'), 418112),
#              (('VBN', 'IN', 'IN'), 418113),
#              (('VBN', 'CD', 'IN'), 418114),
#              (('VBN', 'NNS', 'IN'), 418115),
#              (('VBD', 'NNS', ','), 418116),
#              (('*', 'DT', 'VBD'), 418117),
#              (('*', 'RB', 'VBD'), 418118),
#              (('*', 'VBN', 'VBD'), 418119),
#              (('*', 'TO', 'VBD'), 418120),
#              (('*', 'VB', 'VBD'), 418121),
#              (('*', 'VBZ', 'VBD'), 418122),
#              (('*', 'PRP', 'VBD'), 418123),
#              (('*', 'RBR', 'VBD'), 418124),
#              (('NN', 'NN', 'DT'), 418125),
#              (('VBZ', ',', 'NN'), 418126),
#              (('NN', ',', 'NN'), 418127),
#              (('NN', ',', ','), 418128),
#              (('NN', 'NN', ','), 418129),
#              (('VBD', 'RB', 'VBZ'), 418130),
#              (('VBD', 'VBZ', 'VBZ'), 418131),
#              (('VBD', 'VBG', 'VBZ'), 418132),
#              (('VBD', 'WDT', 'VBZ'), 418133),
#              (('VBD', 'VBP', 'VBZ'), 418134),
#              (('VBD', 'RP', 'VBZ'), 418135),
#              (('VBZ', 'RB', 'JJ'), 418136),
#              (('VBZ', 'RB', 'IN'), 418137),
#              (('VBZ', 'JJ', 'IN'), 418138),
#              (('IN', 'PRP', 'VBZ'), 418139),
#              (('VBZ', 'DT', 'NNS'), 418140),
#              (('VBZ', 'RB', ','), 418141),
#              (('VBZ', 'JJ', ','), 418142),
#              (('VBZ', 'IN', ','), 418143),
#              (('VBZ', 'PRP', ','), 418144),
#              (('VBZ', 'VBZ', ','), 418145),
#              (('VBZ', 'DT', ','), 418146),
#              (('VBZ', 'NNS', ','), 418147),
#              (('VBZ', 'IN', 'IN'), 418148),
#              (('VBZ', 'PRP', 'IN'), 418149),
#              (('VBZ', 'VBZ', 'IN'), 418150),
#              (('VBZ', 'DT', 'IN'), 418151),
#              (('VBZ', 'NNS', 'IN'), 418152),
#              (('VBZ', ',', 'IN'), 418153),
#              (('NNS', 'JJ', 'RB'), 418154),
#              (('VBG', 'TO', 'NNS'), 418155),
#              (('VBG', 'PRP', 'NNS'), 418156),
#              (('IN', 'RB', 'VBG'), 418157),
#              (('IN', 'JJ', 'VBG'), 418158),
#              (('IN', 'NNS', 'VBG'), 418159),
#              (('IN', 'TO', 'VBG'), 418160),
#              (('IN', 'PRP', 'VBG'), 418161),
#              (('NNS', 'WDT', 'VBP'), 418162),
#              (('VBP', 'RP', 'JJ'), 418163),
#              (('VBP', 'NNS', 'JJ'), 418164),
#              (('*', 'VBG', 'VBD'), 418165),
#              (('*', 'WDT', 'VBD'), 418166),
#              (('*', 'VBP', 'VBD'), 418167),
#              (('*', 'RP', 'VBD'), 418168),
#              (('VBD', 'DT', 'NNP'), 418169),
#              (('VBD', 'WDT', 'NNP'), 418170),
#              (('VBD', 'VBZ', 'NNP'), 418171),
#              (('NNP', 'NNP', 'JJ'), 418172),
#              (('IN', 'JJ', 'NNP'), 418173),
#              (('NN', 'IN', 'VBZ'), 418174),
#              (('NN', 'JJ', 'VBZ'), 418175),
#              (('NN', 'NNP', 'VBZ'), 418176),
#              (('NN', 'WDT', 'VBZ'), 418177),
#              (('VBZ', 'NNP', 'NNS'), 418178),
#              (('NNP', 'DT', ','), 418179),
#              (('NNP', 'WDT', ','), 418180),
#              (('NNP', 'VBZ', ','), 418181),
#              (('VBG', 'NN', 'IN'), 418182),
#              (('NNS', 'NN', 'PRP$'), 418183),
#              (('NNS', 'NN', 'NN'), 418184),
#              (('IN', 'PRP$', 'NNS'), 418185),
#              (('VBG', 'IN', 'IN'), 418186),
#              (('VBG', 'PRP$', 'IN'), 418187),
#              (('VBG', 'NNS', 'IN'), 418188),
#              (('VBD', 'VBG', '.'), 418189),
#              (('VBD', 'PRP$', '.'), 418190),
#              (('VBD', 'NNS', '.'), 418191),
#              (('VBD', 'CD', '.'), 418192),
#              (('VBP', 'JJ', 'IN'), 418193),
#              (('VBP', 'NNS', 'IN'), 418194),
#              (('VBP', 'VBD', 'IN'), 418195),
#              (('VBP', 'VBN', 'IN'), 418196),
#              (('VBP', 'RBR', 'IN'), 418197),
#              (('VBP', 'IN', 'IN'), 418198),
#              (('VBP', 'DT', 'IN'), 418199),
#              (('VBP', 'NN', 'IN'), 418200),
#              (('VBP', ',', 'IN'), 418201),
#              (('VBP', 'JJS', 'IN'), 418202),
#              (('IN', 'JJ', 'VBD'), 418203),
#              (('IN', 'NNS', 'VBD'), 418204),
#              (('DT', 'IN', 'RBR'), 418205),
#              (('VBN', 'DT', 'IN'), 418206),
#              (('VBN', 'NN', 'IN'), 418207),
#              (('VBP', 'DT', ','), 418208),
#              (('VBP', 'JJS', ','), 418209),
#              (('VBP', 'NNS', ','), 418210),
#              (('NNS', 'JJS', 'DT'), 418211),
#              (('*', 'IN', 'VBP'), 418212),
#              (('*', 'JJ', 'VBP'), 418213),
#              (('*', 'NNS', 'VBP'), 418214),
#              (('*', 'VBD', 'VBP'), 418215),
#              (('*', 'VBN', 'VBP'), 418216),
#              (('*', 'RBR', 'VBP'), 418217),
#              (('*', 'DT', 'VBP'), 418218),
#              (('*', 'NN', 'VBP'), 418219),
#              (('*', ',', 'VBP'), 418220),
#              (('*', 'JJS', 'VBP'), 418221),
#              (('NNP', 'POS', 'NN'), 418222),
#              (('IN', 'NN', 'NNP'), 418223),
#              (('IN', 'POS', 'NNP'), 418224),
#              (('NNP', 'IN', 'NN'), 418225),
#              (('VB', 'JJ', 'NN'), 418226),
#              (('VB', 'JJ', 'TO'), 418227),
#              (('VB', 'NN', 'TO'), 418228),
#              (('TO', 'DT', 'NN'), 418229),
#              (('VBP', 'IN', '.'), 418230),
#              (('VBP', 'NN', '.'), 418231),
#              (('VBP', 'POS', '.'), 418232),
#              (('VBP', 'NNP', '.'), 418233),
#              (('VBP', ',', '.'), 418234),
#              (('VBP', 'DT', '.'), 418235),
#              (('VBP', 'JJ', '.'), 418236),
#              (('VBP', 'TO', '.'), 418237),
#              (('VBP', 'VB', '.'), 418238),
#              (('VBD', ',', '``'), 418239),
#              (('VBD', '``', 'VBZ'), 418240),
#              (('VBZ', 'DT', 'NN'), 418241),
#              (('VBZ', 'JJ', 'NN'), 418242),
#              (('VBD', ',', '.'), 418243),
#              (('VBD', '``', '.'), 418244),
#              (('VBD', 'VBZ', '.'), 418245),
#              (('*', 'PRP', 'VBP'), 418246),
#              (('IN', 'NNS', 'IN'), 418247),
#              (('IN', 'NN', 'VBD'), 418248),
#              (('IN', 'NN', 'VBG'), 418249),
#              (('NNS', 'JJ', 'DT'), 418250),
#              (('VBG', 'DT', 'NNS'), 418251),
#              (('VBG', 'JJ', 'NNS'), 418252),
#              (('VBP', 'VBG', '.'), 418253),
#              (('VBP', 'NNS', '.'), 418254),
#              (('VBP', 'VBD', '.'), 418255),
#              (('*', 'EX', 'VBZ'), 418256),
#              (('VBZ', 'NN', 'IN'), 418257),
#              (('VBZ', 'DT', 'RB'), 418258),
#              (('VBZ', 'NN', 'RB'), 418259),
#              (('VBZ', 'IN', 'RB'), 418260),
#              (('VBZ', 'PRP$', 'RB'), 418261),
#              (('VBZ', 'NNS', 'RB'), 418262),
#              (('VBZ', 'PRP$', '.'), 418263),
#              (('VBZ', 'NNS', '.'), 418264),
#              (('VBZ', 'RB', '.'), 418265),
#              (('VBZ', 'DT', "''"), 418266),
#              (('VBZ', 'NN', "''"), 418267),
#              (('VBZ', 'IN', "''"), 418268),
#              (('VBZ', 'PRP$', "''"), 418269),
#              (('VBZ', 'NNS', "''"), 418270),
#              (('VBZ', 'RB', "''"), 418271),
#              (('VBZ', '.', "''"), 418272),
#              (('VBD', 'WP', 'NNP'), 418273),
#              (('VBD', 'VBD', 'NNP'), 418274),
#              (('CC', 'DT', 'NNS'), 418275),
#              (('NNS', 'WP', 'VBD'), 418276),
#              (('VBD', 'DT', 'NNS'), 418277),
#              (('*', 'WP', 'VBD'), 418278),
#              (('*', 'VBD', 'VBD'), 418279),
#              (('NNS', 'NNP', 'DT'), 418280),
#              (('IN', 'DT', 'NNS'), 418281),
#              (('IN', 'NNP', 'NNS'), 418282),
#              (('VBD', 'NNP', '.'), 418283),
#              (('VBD', 'PRP', '``'), 418284),
#              (('VBD', 'VBP', '``'), 418285),
#              (('VBD', 'DT', '``'), 418286),
#              (('VBD', 'JJ', '``'), 418287),
#              (('VBD', 'NN', '``'), 418288),
#              (('VBD', 'IN', '``'), 418289),
#              (('VBD', 'NNS', '``'), 418290),
#              (('VBD', "''", '``'), 418291),
#              (('VBD', 'DT', 'VBP'), 418292),
#              (('VBD', 'JJ', 'VBP'), 418293),
#              (('VBD', 'NN', 'VBP'), 418294),
#              (('VBD', 'IN', 'VBP'), 418295),
#              (('VBD', 'NNS', 'VBP'), 418296),
#              (('VBD', 'VBP', 'VBP'), 418297),
#              (('VBD', ',', 'VBP'), 418298),
#              (('VBD', "''", 'VBP'), 418299),
#              (('VBP', 'DT', 'NN'), 418300),
#              (('VBP', 'JJ', 'NN'), 418301),
#              (('IN', 'NNS', 'VBP'), 418302),
#              (('VBD', "''", ','), 418303),
#              (('*', '``', 'VBD'), 418304),
#              (('*', "''", 'VBD'), 418305),
#              (('NNP', 'POS', 'NNP'), 418306),
#              (('VBD', 'POS', '.'), 418307),
#              (('VBD', 'DT', 'NN'), 418308),
#              (('NNP', 'NNP', 'DT'), 418309),
#              (('IN', 'DT', 'NNP'), 418310),
#              (('CC', 'JJ', 'NNS'), 418311),
#              (('CC', 'NNP', 'NNP'), 418312),
#              (('VBD', 'CC', '.'), 418313),
#              (('VBD', 'NN', 'VBD'), 418314),
#              (('IN', '``', 'NNS'), 418315),
#              (('IN', 'RB', 'NNS'), 418316),
#              (('IN', 'JJ', 'NNS'), 418317),
#              (('IN', '``', "''"), 418318),
#              (('IN', 'RB', "''"), 418319),
#              (('IN', 'JJ', "''"), 418320),
#              (('IN', 'NNS', "''"), 418321),
#              (('VBN', '``', 'IN'), 418322),
#              (('VBN', 'RB', 'IN'), 418323),
#              (('VBN', 'JJ', 'IN'), 418324),
#              (('VBN', "''", 'IN'), 418325),
#              (('VBN', 'VBG', 'IN'), 418326),
#              (('CD', 'JJ', 'DT'), 418327),
#              (('IN', 'DT', 'CD'), 418328),
#              (('IN', 'JJ', 'CD'), 418329),
#              (('VBN', 'IN', 'CC'), 418330),
#              (('VBN', '``', 'CC'), 418331),
#              (('VBN', 'RB', 'CC'), 418332),
#              (('VBN', 'JJ', 'CC'), 418333),
#              (('VBN', 'NNS', 'CC'), 418334),
#              (('VBN', "''", 'CC'), 418335),
#              (('VBN', 'VBG', 'CC'), 418336),
#              (('VBN', 'NN', 'CC'), 418337),
#              (('VBN', 'DT', 'CC'), 418338),
#              (('VBN', 'CD', 'CC'), 418339),
#              (('VBD', 'VBD', '.'), 418340),
#              (('VBD', 'RB', '.'), 418341),
#              (('VBD', "''", '.'), 418342),
#              (('VBD', 'CD', 'IN'), 418343),
#              (('VBD', 'TO', 'IN'), 418344),
#              (('VBD', ',', 'IN'), 418345),
#              (('VBD', 'NNP', 'IN'), 418346),
#              (('VBD', 'NNS', 'IN'), 418347),
#              (('VBD', 'IN', 'IN'), 418348),
#              (('VBD', 'DT', 'IN'), 418349),
#              (('IN', 'CD', 'TO'), 418350),
#              (('VBD', 'CD', ','), 418351),
#              (('VBD', 'NNP', ','), 418352),
#              (('VBD', 'IN', ','), 418353),
#              (('VBD', 'DT', ','), 418354),
#              (('NNS', 'NNP', 'CD'), 418355),
#              (('VBD', 'IN', 'NNS'), 418356),
#              (('VBD', 'NNS', 'NNS'), 418357),
#              (('VBD', 'VBN', 'VBD'), 418358),
#              (('VBD', ',', 'VBD'), 418359),
#              (('VBD', 'DT', 'VBD'), 418360),
#              (('VBD', 'NN', ','), 418361),
#              (('VBP', 'CD', 'IN'), 418362),
#              (('VBP', 'WP', 'IN'), 418363),
#              (('VBP', 'RB', 'IN'), 418364),
#              (('IN', 'CD', 'NNS'), 418365),
#              (('VBD', 'RB', 'IN'), 418366),
#              (('VBP', 'CD', ','), 418367),
#              (('*', 'CD', 'VBP'), 418368),
#              (('*', 'WP', 'VBP'), 418369),
#              (('*', 'RB', 'VBP'), 418370),
#              (('NNS', 'IN', 'JJ'), 418371),
#              (('NNS', 'CD', 'JJ'), 418372),
#              (('NNS', 'CD', 'IN'), 418373),
#              (('NN', 'DT', 'NNS'), 418374),
#              (('NN', 'VBN', 'NNS'), 418375),
#              (('NN', 'VBN', 'DT'), 418376),
#              (('VBN', ':', 'NN'), 418377),
#              (('VBN', 'IN', 'NN'), 418378),
#              (('VBN', 'CD', 'NN'), 418379),
#              (('VBN', 'NNS', 'NN'), 418380),
#              (('VBN', 'VBN', 'NN'), 418381),
#              (('VBP', 'VBN', '.'), 418382),
#              (('VBP', ':', '.'), 418383),
#              (('VBP', 'CD', '.'), 418384),
#              (('VBP', 'IN', 'CD'), 418385),
#              (('VBP', 'DT', 'CD'), 418386),
#              (('VBP', 'CD', 'CD'), 418387),
#              (('VBP', 'VBG', 'CD'), 418388),
#              (('VBP', 'NNS', 'CD'), 418389),
#              (('NNS', 'CD', 'DT'), 418390),
#              (('NNS', 'VBG', 'DT'), 418391),
#              (('NNS', 'VBG', 'CD'), 418392),
#              (('IN', 'VBG', 'NNS'), 418393),
#              (('*', 'VBG', 'VBP'), 418394),
#              (('VBP', 'JJ', 'NNS'), 418395),
#              (('VBP', 'JJ', ','), 418396),
#              (('VBP', 'JJ', 'VBG'), 418397),
#              (('VBP', 'NNS', 'VBG'), 418398),
#              (('VBP', ',', 'VBG'), 418399),
#              (('IN', 'RB', 'NN'), 418400),
#              (('IN', 'VBN', 'NN'), 418401),
#              (('VBP', 'RB', '.'), 418402),
#              (('VBD', 'IN', 'NN'), 418403),
#              (('VBD', 'CD', 'NN'), 418404),
#              (('VBD', 'NNS', 'NN'), 418405),
#              (('VBD', 'JJ', 'NN'), 418406),
#              (('VBD', 'NN', 'NN'), 418407),
#              (('VBD', ',', 'NN'), 418408),
#              (('VBD', 'CC', 'NN'), 418409),
#              (('NN', 'NN', 'NN'), 418410),
#              (('VBD', 'RB', 'VBD'), 418411),
#              (('VBD', 'JJR', 'VBD'), 418412),
#              (('VBD', 'IN', 'VBD'), 418413),
#              (('VBD', 'NNS', 'VBD'), 418414),
#              (('VBD', 'RB', 'JJR'), 418415),
#              (('*', 'JJR', 'VBD'), 418416),
#              (('VBD', 'VBZ', '``'), 418417),
#              (('VBD', 'WP', '``'), 418418),
#              (('VBD', 'WP', 'VBZ'), 418419),
#              (('VBD', "''", 'VBZ'), 418420),
#              (('DT', 'IN', 'VBP'), 418421),
#              (('DT', 'PRP', 'VBP'), 418422),
#              (('DT', 'WP', 'VBP'), 418423),
#              (('NN', ',', 'DT'), 418424),
#              (('NNP', ',', 'NNP'), 418425),
#              (('NN', ',', 'NNP'), 418426),
#              (('NN', 'NN', 'NNP'), 418427),
#              (('IN', 'NNP', 'NN'), 418428),
#              (('IN', ',', 'NN'), 418429),
#              (('IN', 'NN', 'NN'), 418430),
#              (('VBD', 'VB', 'VBZ'), 418431),
#              (('VBD', 'JJS', 'VBZ'), 418432),
#              (('VB', 'DT', 'JJS'), 418433),
#              (('NNS', 'NN', 'DT'), 418434),
#              (('NNS', 'VBN', 'JJ'), 418435),
#              (('IN', 'VBN', 'NNS'), 418436),
#              (('VBD', 'PRP', ','), 418437),
#              (('*', 'JJS', 'VBD'), 418438),
#              (('VBD', 'WDT', 'NN'), 418439),
#              (('VBD', 'VBZ', 'NN'), 418440),
#              (('VBD', 'VBN', 'NN'), 418441),
#              (('VBD', 'NNP', 'NN'), 418442),
#              (('NN', ',', 'VBZ'), 418443),
#              (('NNP', 'CC', 'NNP'), 418444),
#              (('IN', 'CC', 'NNP'), 418445),
#              (('NN', 'WDT', ','), 418446),
#              (('NN', 'VBZ', ','), 418447),
#              (('NN', 'VBN', ','), 418448),
#              (('NN', 'IN', ','), 418449),
#              (('NN', 'NNP', ','), 418450),
#              (('NN', 'CC', ','), 418451),
#              (('NN', 'IN', 'TO'), 418452),
#              (('NN', 'NN', 'TO'), 418453),
#              (('VB', 'DT', 'NNS'), 418454),
#              (('VBD', 'TO', '.'), 418455),
#              (('VBD', 'VB', '.'), 418456),
#              (('MD', 'RB', 'NN'), 418457),
#              (('VBD', 'VB', 'MD'), 418458),
#              (('VBD', 'DT', 'MD'), 418459),
#              (('VBD', 'WP', 'MD'), 418460),
#              (('VBD', 'VBP', 'MD'), 418461),
#              (('VBD', 'IN', 'MD'), 418462),
#              (('VBD', 'NNP', 'MD'), 418463),
#              (('VBD', 'MD', 'MD'), 418464),
#              (('VBD', 'NN', 'MD'), 418465),
#              (('VBD', 'VBG', 'MD'), 418466),
#              (('VBD', 'RBR', 'MD'), 418467),
#              (('VBD', 'RB', 'MD'), 418468),
#              (('VBD', 'JJ', 'MD'), 418469),
#              (('VBD', ',', 'MD'), 418470),
#              (('VBD', 'VBN', 'MD'), 418471),
#              (('VBD', 'JJS', 'MD'), 418472),
#              (('VBD', 'NNS', 'MD'), 418473),
#              (('VBD', 'CC', 'MD'), 418474),
#              (('IN', 'DT', 'MD'), 418475),
#              (('IN', 'NNP', 'MD'), 418476),
#              (('NN', 'IN', 'VBG'), 418477),
#              (('NN', 'NN', 'VBG'), 418478),
#              (('VB', 'DT', 'RB'), 418479),
#              (('VB', 'NN', 'RB'), 418480),
#              (('VB', 'IN', 'RB'), 418481),
#              (('VB', 'VBG', 'RB'), 418482),
#              (('VB', 'RBR', 'RB'), 418483),
#              (('NN', 'IN', 'NN'), 418484),
#              (('NN', ',', 'VBN'), 418485),
#              (('IN', 'JJS', 'NNS'), 418486),
#              (('*', 'MD', 'VBD'), 418487),
#              (('*', 'DT', 'VBZ'), 418488),
#              (('NNS', 'VBN', 'DT'), 418489),
#              (('NNS', 'WDT', 'VBZ'), 418490),
#              (('VBZ', 'RB', 'VB'), 418491),
#              (('NN', 'JJR', 'DT'), 418492),
#              (('VB', 'JJR', 'NN'), 418493),
#              (('NNS', ',', 'DT'), 418494),
#              (('NNS', ',', 'JJ'), 418495),
#              (('NNS', 'JJ', 'JJ'), 418496),
#              (('NNS', 'JJ', ','), 418497),
#              (('IN', ',', 'NNS'), 418498),
#              (('NNS', 'JJ', 'IN'), 418499),
#              (('NNS', 'JJ', 'VBP'), 418500),
#              (('NNS', 'IN', 'VBP'), 418501),
#              (('NNS', 'NN', 'VBP'), 418502),
#              (('VBZ', 'CD', ','), 418503),
#              (('VBZ', 'VBN', ','), 418504),
#              (('VBZ', 'WDT', ','), 418505),
#              (('VBZ', 'VB', ','), 418506),
#              (('VBZ', 'JJR', ','), 418507),
#              (('VBZ', 'NN', ','), 418508),
#              (('VBZ', ',', ','), 418509),
#              (('VBZ', 'VBP', ','), 418510),
#              (('VBZ', 'CD', 'VBG'), 418511),
#              (('VBZ', 'IN', 'VBG'), 418512),
#              (('VBZ', 'DT', 'VBG'), 418513),
#              (('VBZ', 'JJ', 'VBG'), 418514),
#              (('VBZ', 'VBN', 'VBG'), 418515),
#              (('VBZ', 'NNS', 'VBG'), 418516),
#              (('VBZ', 'WDT', 'VBG'), 418517),
#              (('VBZ', 'VBZ', 'VBG'), 418518),
#              (('VBZ', 'RB', 'VBG'), 418519),
#              (('VBZ', 'VB', 'VBG'), 418520),
#              (('VBZ', 'JJR', 'VBG'), 418521),
#              (('VBZ', 'NN', 'VBG'), 418522),
#              (('VBZ', ',', 'VBG'), 418523),
#              (('VBZ', 'VBP', 'VBG'), 418524),
#              (('TO', 'NNP', 'NNP'), 418525),
#              (('NNP', 'IN', 'DT'), 418526),
#              (('NNP', 'IN', 'NNP'), 418527),
#              (('IN', 'IN', 'NNP'), 418528),
#              (('VBZ', 'CD', '.'), 418529),
#              (('VBZ', 'JJ', '.'), 418530),
#              (('VBZ', 'VBN', '.'), 418531),
#              (('VBZ', 'WDT', '.'), 418532),
#              (('VBZ', 'VBZ', '.'), 418533),
#              (('VBZ', 'VB', '.'), 418534),
#              (('VBZ', 'JJR', '.'), 418535),
#              (('VBZ', 'VBP', '.'), 418536),
#              (('VBZ', 'TO', '.'), 418537),
#              (('NNS', 'JJ', 'RBR'), 418538),
#              (('NNS', 'NN', 'RBR'), 418539),
#              (('NNS', 'NN', 'JJ'), 418540),
#              (('VBD', 'CC', 'VBP'), 418541),
#              (('VBD', 'RBR', 'VBP'), 418542),
#              (('VBD', 'RB', 'VBP'), 418543),
#              (('VBD', 'VBN', 'VBP'), 418544),
#              (('VBD', 'NNP', 'VBP'), 418545),
#              (('VBP', 'JJ', 'CC'), 418546),
#              (('VBP', 'RBR', 'VBN'), 418547),
#              (('VBP', 'RB', 'VBN'), 418548),
#              (('VBD', 'JJ', 'IN'), 418549),
#              (('VBD', 'NN', 'IN'), 418550),
#              (('MD', 'CD', 'IN'), 418551),
#              (('MD', ',', 'IN'), 418552),
#              (('MD', 'RB', 'IN'), 418553),
#              (('MD', 'DT', 'IN'), 418554),
#              (('MD', 'VBG', 'IN'), 418555),
#              (('MD', 'NNS', 'IN'), 418556),
#              (('MD', 'IN', 'IN'), 418557),
#              (('MD', 'JJ', 'IN'), 418558),
#              (('MD', 'NN', 'IN'), 418559),
#              (('MD', 'RB', ','), 418560),
#              (('MD', 'DT', ','), 418561),
#              (('MD', 'VBG', ','), 418562),
#              (('MD', 'NNS', ','), 418563),
#              (('MD', 'IN', ','), 418564),
#              (('MD', 'JJ', ','), 418565),
#              (('MD', 'NN', ','), 418566),
#              (('MD', 'IN', 'NNS'), 418567),
#              (('MD', 'JJ', 'NNS'), 418568),
#              (('MD', 'NN', 'NNS'), 418569),
#              (('*', 'IN', 'MD'), 418570),
#              (('*', 'RB', 'MD'), 418571),
#              (('*', 'DT', 'MD'), 418572),
#              (('*', 'VBG', 'MD'), 418573),
#              (('*', 'NN', 'MD'), 418574),
#              (('MD', 'VBN', '.'), 418575),
#              (('VBD', 'NN', 'NNS'), 418576),
#              (('VBD', 'WDT', 'NNS'), 418577),
#              (('VBD', 'VBD', 'NNS'), 418578),
#              (('VBD', 'NNP', 'NNS'), 418579),
#              (('NN', 'WDT', 'VBD'), 418580),
#              (('VBD', 'RB', 'JJ'), 418581),
#              (('VBD', 'DT', 'WRB'), 418582),
#              (('VBD', 'NN', 'WRB'), 418583),
#              (('VBD', 'JJ', 'VBD'), 418584),
#              (('VBD', 'WRB', 'VBD'), 418585),
#              (('VBD', 'WRB', '.'), 418586),
#              (('VBD', 'JJ', 'NNS'), 418587),
#              (('VBD', 'VBN', 'IN'), 418588),
#              (('VBD', 'JJ', ','), 418589),
#              (('VBD', 'VBN', ','), 418590),
#              (('NNS', 'CC', 'NN'), 418591),
#              (('VBD', 'RP', 'NNS'), 418592),
#              (('VBD', 'CC', 'NNS'), 418593),
#              (('VBD', 'RP', 'CC'), 418594),
#              (('VBD', 'NN', 'CC'), 418595),
#              (('VBD', 'CC', 'CC'), 418596),
#              (('VBD', 'NNS', 'CC'), 418597),
#              (('CC', 'RB', 'VBD'), 418598),
#              (('VBD', 'RP', '.'), 418599),
#              (('VBD', '``', 'NNS'), 418600),
#              (('NNS', 'IN', "''"), 418601),
#              (('NNS', 'JJ', "''"), 418602),
#              (('NNS', 'NN', "''"), 418603),
#              (('NNS', 'IN', 'VBD'), 418604),
#              (('NNS', 'JJ', 'VBD'), 418605),
#              (('NNS', 'NN', 'VBD'), 418606),
#              (('NNS', "''", 'VBD'), 418607),
#              (('NNS', 'WDT', 'VBD'), 418608),
#              (('VBD', 'WDT', '.'), 418609),
#              (('VBD', 'EX', '``'), 418610),
#              (('VBD', 'CC', '``'), 418611),
#              (('VBD', 'VBD', '``'), 418612),
#              (('VBD', 'CC', 'VBZ'), 418613),
#              (('VBD', 'VBD', 'VBZ'), 418614),
#              (('VBD', 'IN', 'DT'), 418615),
#              (('VBD', 'DT', 'DT'), 418616),
#              (('VBD', 'NNS', 'DT'), 418617),
#              (('VBD', 'CC', 'DT'), 418618),
#              (('IN', 'DT', 'VBD'), 418619),
#              (('IN', 'IN', 'VBD'), 418620),
#              (('IN', 'CC', 'VBD'), 418621),
#              (('*', 'EX', 'VBD'), 418622),
#              (('NNP', 'NN', 'NN'), 418623),
#              (('NN', 'JJ', 'IN'), 418624),
#              (('VBP', 'CC', '``'), 418625),
#              (('VBP', 'PRP', '``'), 418626),
#              (('VBP', 'PRP', 'CC'), 418627),
#              (('*', '``', 'VBP'), 418628),
#              (('*', 'CC', 'VBP'), 418629),
#              (('*', 'PRP', 'VBZ'), 418630),
#              (('NN', 'NN', 'PRP$'), 418631),
#              (('IN', 'PRP$', 'NN'), 418632),
#              (('VBD', 'TO', ','), 418633),
#              (('VBD', 'VB', ','), 418634),
#              (('VBD', 'VB', 'IN'), 418635),
#              (('IN', 'NN', 'VBP'), 418636),
#              (('VBD', 'VBP', '.'), 418637),
#              (('NN', 'NN', 'JJ'), 418638),
#              (('VBD', 'POS', 'NN'), 418639),
#              (('NNS', 'JJ', 'CD'), 418640),
#              (('*', 'POS', 'VBD'), 418641),
#              (('VBD', 'DT', 'TO'), 418642),
#              (('VBD', 'NN', 'TO'), 418643),
#              (('VBD', 'IN', 'TO'), 418644),
#              (('TO', 'CD', 'NN'), 418645),
#              (('IN', 'CD', 'NN'), 418646),
#              (('NN', 'IN', 'CC'), 418647),
#              (('NN', 'NNS', 'CC'), 418648),
#              (('IN', 'DT', 'VBZ'), 418649),
#              (('IN', 'JJ', 'VBZ'), 418650),
#              (('IN', 'NN', 'VBZ'), 418651),
#              (('VBP', 'CC', '.'), 418652),
#              (('VBP', 'VBZ', '.'), 418653),
#              (('NNS', 'POS', 'NNS'), 418654),
#              (('IN', 'NNS', 'NNS'), 418655),
#              (('IN', 'POS', 'NNS'), 418656),
#              (('TO', 'CD', 'NNS'), 418657),
#              (('NNS', ',', 'JJS'), 418658),
#              (('NNS', 'DT', 'JJS'), 418659),
#              (('NNS', ',', ','), 418660),
#              (('NNS', 'DT', ','), 418661),
#              (('NNS', 'JJS', ','), 418662),
#              (('NNS', 'IN', ','), 418663),
#              (('NNS', 'NNP', ','), 418664),
#              (('VBD', 'IN', 'VBG'), 418665),
#              (('VBD', 'DT', 'VBG'), 418666),
#              (('VBD', 'NN', 'VBG'), 418667),
#              (('VBD', 'TO', 'VBG'), 418668),
#              (('VBD', 'CD', 'VBG'), 418669),
#              (('VBD', 'NNS', 'VBG'), 418670),
#              (('VBD', ',', 'VBG'), 418671),
#              (('VBD', 'JJS', 'VBG'), 418672),
#              (('VBD', 'JJ', 'VBG'), 418673),
#              (('VBD', 'NNP', 'VBG'), 418674),
#              (('VBD', 'JJS', '.'), 418675),
#              (('*', 'JJR', 'VBP'), 418676),
#              (('NNS', 'NN', 'VBG'), 418677),
#              (('VB', 'VBG', 'NNS'), 418678),
#              (('VB', 'VBG', 'IN'), 418679),
#              (('VB', 'NNS', 'IN'), 418680),
#              (('IN', 'PRP', 'VBP'), 418681),
#              (('VBP', 'NN', 'TO'), 418682),
#              (('VBP', 'NNS', 'TO'), 418683),
#              (('NNS', 'JJR', 'RB'), 418684),
#              (('VB', 'RB', 'NNS'), 418685),
#              (('VB', 'JJR', 'NNS'), 418686),
#              (('VB', 'RB', 'IN'), 418687),
#              (('VB', 'JJR', 'IN'), 418688),
#              (('IN', 'JJR', 'NN'), 418689),
#              (('VBP', 'PRP', '.'), 418690),
#              (('VBP', 'VBP', '.'), 418691),
#              (('VBP', 'JJR', '.'), 418692),
#              (('IN', 'NN', 'MD'), 418693),
#              (('IN', 'NNS', 'MD'), 418694),
#              (('VB', 'JJR', 'RB'), 418695),
#              (('VB', 'NNS', 'RB'), 418696),
#              (('VBP', 'MD', '.'), 418697),
#              (('VBD', 'RB', 'NN'), 418698),
#              (('VBD', 'TO', 'NN'), 418699),
#              (('VBD', 'VB', 'NN'), 418700),
#              (('VBD', 'JJR', 'NN'), 418701),
#              (('VBD', 'VBP', 'NN'), 418702),
#              (('JJ', 'RB', 'TO'), 418703),
#              (('NN', 'NNS', ','), 418704),
#              (('NN', 'JJ', ','), 418705),
#              (('NN', 'RB', ','), 418706),
#              (('NN', 'TO', ','), 418707),
#              (('NN', 'NNS', 'VBN'), 418708),
#              (('NN', 'JJ', 'VBN'), 418709),
#              (('NN', 'TO', 'VBN'), 418710),
#              (('VBN', 'IN', 'TO'), 418711),
#              (('VBN', 'DT', 'TO'), 418712),
#              (('IN', 'DT', 'VBP'), 418713),
#              (('VBP', 'DT', 'RB'), 418714),
#              (('VBP', 'NN', 'RB'), 418715),
#              (('NN', 'DT', ','), 418716),
#              (('NN', 'VB', ','), 418717),
#              (('NN', 'JJR', ','), 418718),
#              (('NN', 'VBP', ','), 418719),
#              (('NNS', 'CD', ':'), 418720),
#              (('NN', 'IN', 'NNS'), 418721),
#              (('NN', 'NN', 'NNS'), 418722),
#              (('NN', ':', 'NNS'), 418723),
#              (('NN', 'CD', 'NNS'), 418724),
#              (('VBD', ':', '.'), 418725),
#              (('MD', ',', 'RB'), 418726),
#              (('MD', 'VBD', 'RB'), 418727),
#              (('MD', 'NNP', 'RB'), 418728),
#              (('MD', 'NN', 'RB'), 418729),
#              (('MD', 'IN', 'RB'), 418730),
#              (('MD', 'NNS', 'RB'), 418731),
#              (('MD', '``', 'RB'), 418732),
#              (('MD', 'NNP', 'VBD'), 418733),
#              (('MD', ',', 'VBD'), 418734),
#              (('MD', 'NN', 'VBD'), 418735),
#              (('MD', 'IN', 'VBD'), 418736),
#              (('MD', 'NNS', 'VBD'), 418737),
#              (('MD', '``', 'VBD'), 418738),
#              (('VBD', ',', ','), 418739),
#              (('MD', '``', 'NNS'), 418740),
#              (('*', 'VBD', 'MD'), 418741),
#              (('*', '``', 'MD'), 418742),
#              (('VB', 'RP', 'RB'), 418743),
#              (('VB', 'RP', 'IN'), 418744),
#              (('VB', 'RP', "''"), 418745),
#              (('VB', 'RB', "''"), 418746),
#              (('VB', 'IN', "''"), 418747),
#              (('VB', 'PRP', "''"), 418748),
#              (('VB', 'VBP', "''"), 418749),
#              (('VB', 'IN', 'IN'), 418750),
#              (('VB', 'PRP', 'IN'), 418751),
#              (('VB', 'VBP', 'IN'), 418752),
#              (('VB', "''", 'IN'), 418753),
#              (('IN', 'IN', 'NNS'), 418754),
#              (('MD', 'RP', '.'), 418755),
#              (('MD', 'RB', '.'), 418756),
#              (('MD', 'PRP', '.'), 418757),
#              (('MD', 'VBP', '.'), 418758),
#              (('MD', "''", '.'), 418759),
#              (('MD', 'NNS', '.'), 418760),
#              (('NNS', 'NNP', 'JJ'), 418761),
#              (('NN', 'POS', 'NNP'), 418762),
#              (('IN', 'POS', 'NN'), 418763),
#              (('VBD', 'CD', 'NNS'), 418764),
#              (('$', 'CD', 'CD'), 418765),
#              (('VBD', '$', 'IN'), 418766),
#              (('NN', 'JJS', 'DT'), 418767),
#              (('IN', 'JJS', 'NN'), 418768),
#              (('VBD', '$', ','), 418769),
#              (('VBD', 'JJS', ','), 418770),
#              (('VBD', '$', 'TO'), 418771),
#              (('VBD', 'CD', 'TO'), 418772),
#              (('VBD', 'JJS', 'TO'), 418773),
#              (('VBD', ',', 'TO'), 418774),
#              (('VBD', '$', '.'), 418775),
#              (('VBP', ',', 'RB'), 418776),
#              (('VBP', 'NNS', 'RB'), 418777),
#              (('VBP', 'NN', ','), 418778),
#              (('VB', 'NNS', 'CC'), 418779),
#              (('VBP', 'JJS', '.'), 418780),
#              (('VBP', 'RB', 'VBG'), 418781),
#              (('NN', 'IN', 'RB'), 418782),
#              (('NN', 'CD', 'RB'), 418783),
#              (('RB', 'IN', 'CD'), 418784),
#              (('VBG', 'RB', 'NN'), 418785),
#              (('VBG', 'IN', 'NN'), 418786),
#              (('VBG', 'CD', 'NN'), 418787),
#              (('NNP', 'JJ', 'NN'), 418788),
#              (('VBD', 'DT', 'RB'), 418789),
#              (('VBD', 'JJ', 'RB'), 418790),
#              (('VBD', 'NN', 'RB'), 418791),
#              (('VBD', 'IN', 'RB'), 418792),
#              (('VBD', 'CD', 'RB'), 418793),
#              (('VBD', 'JJS', 'RB'), 418794),
#              (('VBD', ',', 'RB'), 418795),
#              (('IN', 'CD', 'JJR'), 418796),
#              (('IN', 'NN', 'JJR'), 418797),
#              (('IN', 'DT', 'JJR'), 418798),
#              (('VBD', 'JJR', '.'), 418799),
#              (('VBZ', 'RB', 'RB'), 418800),
#              (('VBZ', 'JJ', 'RB'), 418801),
#              (('VBZ', 'RB', 'CC'), 418802),
#              (('VBZ', 'IN', 'CC'), 418803),
#              (('VBZ', 'JJ', 'CC'), 418804),
#              (('VBZ', 'NNS', 'CC'), 418805),
#              (('VBG', 'NN', 'NNS'), 418806),
#              (('VBG', 'NN', ','), 418807),
#              (('VBG', 'NNS', ','), 418808),
#              (('VBG', 'NN', 'VBZ'), 418809),
#              (('VBG', 'NNS', 'VBZ'), 418810),
#              (('VBG', ',', 'VBZ'), 418811),
#              (('VBG', 'WDT', 'VBZ'), 418812),
#              (('VBZ', 'PRP$', 'NN'), 418813),
#              (('VBZ', 'CC', '.'), 418814),
#              (('NN', 'CD', 'DT'), 418815),
#              (('NN', 'CD', 'JJ'), 418816),
#              (('TO', 'JJ', 'NN'), 418817),
#              (('VBD', 'TO', ':'), 418818),
#              (('VBD', 'DT', ':'), 418819),
#              (('VBD', 'JJ', ':'), 418820),
#              (('VBD', 'CD', ':'), 418821),
#              (('VBD', 'NN', ':'), 418822),
#              (('VBD', 'IN', ':'), 418823),
#              (('VBD', 'TO', 'VBD'), 418824),
#              (('VBD', 'CD', 'VBD'), 418825),
#              (('VBD', ':', 'VBD'), 418826),
#              (('NNP', 'CC', 'VBZ'), 418827),
#              (('NNP', 'NNP', 'VBZ'), 418828),
#              (('NNP', ',', 'VBZ'), 418829),
#              (('NNP', 'WDT', 'VBZ'), 418830),
#              (('VBZ', 'CD', 'NN'), 418831),
#              (('VBZ', 'NNP', 'NNP'), 418832),
#              (('NN', 'DT', 'RB'), 418833),
#              (('NN', 'NNP', 'RB'), 418834),
#              (('NN', 'NN', 'RB'), 418835),
#              (('NN', 'NNP', 'NNP'), 418836),
#              (('NNP', 'RB', 'NN'), 418837),
#              (('NNP', 'RB', ','), 418838),
#              (('NNP', ',', 'VBD'), 418839),
#              (('NNP', 'RB', 'VBD'), 418840),
#              (('NNP', 'DT', 'VBD'), 418841),
#              (('NNP', 'NNP', 'VBD'), 418842),
#              (('NNP', 'NN', 'VBD'), 418843),
#              (('NNP', 'WP', 'VBD'), 418844),
#              (('VBZ', 'WP', '.'), 418845),
#              (('VBZ', 'VBD', '.'), 418846),
#              (('NNS', 'POS', 'NNP'), 418847),
#              (('NNS', 'CD', 'NNP'), 418848),
#              (('NNS', 'NN', 'CD'), 418849),
#              (('VBZ', 'POS', '.'), 418850),
#              (('VBD', 'PRP$', 'NN'), 418851),
#              (('NN', 'NNP', 'IN'), 418852),
#              (('$', 'CD', 'NN'), 418853),
#              (('$', 'DT', 'NN'), 418854),
#              (('$', 'CD', ','), 418855),
#              (('$', 'DT', ','), 418856),
#              (('$', 'NN', ','), 418857),
#              (('$', 'CD', 'CC'), 418858),
#              (('$', 'DT', 'CC'), 418859),
#              (('$', 'NN', 'CC'), 418860),
#              (('$', ',', 'CC'), 418861),
#              (('NN', 'VBG', 'NN'), 418862),
#              (('VB', 'JJ', 'CC'), 418863),
#              (('VB', 'NN', 'CC'), 418864),
#              (('VB', 'JJ', 'IN'), 418865),
#              (('VB', 'CC', 'IN'), 418866),
#              (('VB', 'VB', 'IN'), 418867),
#              (('VBD', 'PRP', '.'), 418868),
#              (('NN', 'NNP', 'PRP$'), 418869),
#              (('NN', 'CC', 'PRP$'), 418870),
#              (('NN', 'CC', 'NNP'), 418871),
#              (('VBD', 'PRP$', 'VBD'), 418872),
#              (('VBD', 'NNP', 'VBD'), 418873),
#              (('VBD', 'CC', 'VBD'), 418874),
#              (('NNP', 'NNP', 'PRP$'), 418875),
#              (('IN', 'PRP$', 'NNP'), 418876),
#              (('NN', 'PRP$', 'TO'), 418877),
#              (('NN', 'NNP', 'TO'), 418878),
#              (('NNP', '.', 'NNP'), 418879),
#              (('TO', '.', 'NNP'), 418880),
#              (('NN', 'PRP$', 'IN'), 418881),
#              (('NN', 'TO', 'IN'), 418882),
#              (('NN', '.', 'IN'), 418883),
#              (('VBD', '.', '.'), 418884),
#              (('NN', 'VBG', 'JJ'), 418885),
#              (('VBZ', 'VBG', 'NN'), 418886),
#              (('VBZ', ',', 'NNP'), 418887),
#              (('VBZ', 'VBN', 'NNP'), 418888),
#              (('VBZ', 'IN', 'NNP'), 418889),
#              (('NNP', ',', 'VBN'), 418890),
#              (('NNP', 'VBN', ','), 418891),
#              (('*', ',', 'VBZ'), 418892),
#              (('*', 'VBN', 'VBZ'), 418893),
#              (('*', 'IN', 'VBZ'), 418894),
#              (('NNS', 'NNS', 'JJ'), 418895),
#              (('VBZ', 'JJ', 'NNS'), 418896),
#              (('VBZ', 'NNS', 'NNS'), 418897),
#              (('VBZ', 'CD', 'NNS'), 418898),
#              (('VBZ', 'CD', 'CC'), 418899),
#              (('IN', 'IN', '$'), 418900),
#              (('VBZ', '$', '.'), 418901),
#              (('NNS', 'NNS', 'NNP'), 418902),
#              (('IN', 'NNP', 'VBZ'), 418903),
#              (('VBZ', 'RB', 'VBN'), 418904),
#              (('VBZ', 'NNP', 'IN'), 418905),
#              (('VBD', 'NNP', 'VBZ'), 418906),
#              (('VB', 'JJ', 'NNS'), 418907),
#              (('NN', 'POS', 'NN'), 418908),
#              (('VBD', 'NNP', 'TO'), 418909),
#              (('VB', 'NN', 'NN'), 418910),
#              (('*', 'NN', 'VBZ'), 418911),
#              (('*', 'TO', 'VBZ'), 418912),
#              (('*', 'VB', 'VBZ'), 418913),
#              (('VB', 'DT', 'TO'), 418914),
#              (('VBZ', 'TO', ','), 418915),
#              (('VBZ', '$', ','), 418916),
#              (('VBZ', 'VBN', 'CC'), 418917),
#              (('VBZ', 'TO', 'CC'), 418918),
#              (('VBZ', 'VB', 'CC'), 418919),
#              (('VBZ', 'DT', 'CC'), 418920),
#              (('VBZ', 'NN', 'CC'), 418921),
#              (('VBZ', '$', 'CC'), 418922),
#              (('VBZ', ',', 'CC'), 418923),
#              (('CC', 'DT', 'VBZ'), 418924),
#              (('CC', 'NNP', 'VBZ'), 418925),
#              (('IN', 'DT', 'JJS'), 418926),
#              (('VBZ', 'JJS', '.'), 418927),
#              (('VB', 'NNP', 'IN'), 418928),
#              (('VB', 'CD', 'IN'), 418929),
#              (('VBD', 'MD', '.'), 418930),
#              (('VBN', 'NN', 'NN'), 418931),
#              (('NN', 'NNS', 'DT'), 418932),
#              (('NN', 'CC', 'DT'), 418933),
#              (('NN', 'NNS', 'NNP'), 418934),
#              (('NN', 'CC', 'NNS'), 418935),
#              (('NN', 'NN', 'CC'), 418936),
#              (('IN', 'NNS', 'NN'), 418937),
#              (('IN', 'CC', 'NN'), 418938),
#              (('NNP', 'NN', 'JJ'), 418939),
#              (('MD', 'PRP', 'IN'), 418940),
#              (('*', 'PRP', 'MD'), 418941),
#              (('NNS', 'NNP', 'NNP'), 418942),
#              (('VB', 'POS', 'NNS'), 418943),
#              (('NNS', ',', 'NN'), 418944),
#              (('NN', ',', 'NNS'), 418945),
#              (('MD', 'POS', '.'), 418946),
#              (('MD', ',', '.'), 418947),
#              (('MD', 'CC', '.'), 418948),
#              (('VBD', 'NNP', 'RB'), 418949),
#              (('VBD', 'NNS', 'RB'), 418950),
#              (('VBN', 'CC', 'NN'), 418951),
#              (('VBN', 'CC', 'IN'), 418952),
#              (('VBN', 'NNP', 'IN'), 418953),
#              (('VBZ', 'PRP', 'WRB'), 418954),
#              (('VBP', 'NN', 'VBZ'), 418955),
#              (('VBP', 'IN', 'VBZ'), 418956),
#              (('VBP', 'PRP$', 'VBZ'), 418957),
#              (('VBP', 'JJ', 'VBZ'), 418958),
#              (('VBP', ',', 'VBZ'), 418959),
#              (('VBP', 'DT', 'VBZ'), 418960),
#              (('VBP', 'POS', 'VBZ'), 418961),
#              (('VBP', 'VBG', 'VBZ'), 418962),
#              (('VBP', 'NNS', 'VBZ'), 418963),
#              (('VBP', 'RB', 'VBZ'), 418964),
#              (('NN', 'JJ', 'PRP$'), 418965),
#              (('VBP', 'POS', ','), 418966),
#              (('VBP', 'VBG', ','), 418967),
#              (('VBP', 'RB', ','), 418968),
#              (('NNS', 'POS', 'NN'), 418969),
#              (('NNS', 'VBG', 'NN'), 418970),
#              (('VBP', 'RB', 'NNS'), 418971),
#              (('*', 'WRB', 'VBP'), 418972),
#              (('*', 'VBZ', 'VBP'), 418973),
#              (('*', 'PRP$', 'VBP'), 418974),
#              (('*', 'POS', 'VBP'), 418975),
#              (('VBP', 'RP', 'TO'), 418976),
#              (('TO', 'DT', 'NNS'), 418977),
#              (('TO', 'JJ', 'NNS'), 418978),
#              (('VBP', 'RP', '.'), 418979),
#              (('*', 'RB', 'NN'), 418980),
#              (('*', 'DT', 'NN'), 418981),
#              (('VBD', 'DT', 'CC'), 418982),
#              (('VB', 'PRP$', 'NNS'), 418983),
#              (('VB', 'PRP$', 'IN'), 418984),
#              (('CC', 'NN', 'NNS'), 418985),
#              (('IN', 'NN', 'IN'), 418986),
#              (('IN', 'CC', 'IN'), 418987),
#              (('NN', ',', 'IN'), 418988),
#              (('NN', ',', ':'), 418989),
#              (('NN', 'IN', ':'), 418990),
#              (('NN', 'NN', ':'), 418991),
#              (('NN', ',', 'TO'), 418992),
#              (('NN', ':', 'TO'), 418993),
#              (('TO', 'NN', 'NNS'), 418994),
#              (('VB', 'TO', 'IN'), 418995),
#              (('IN', 'IN', 'VBZ'), 418996),
#              (('IN', 'DT', ','), 418997),
#              (('IN', 'NN', ','), 418998),
#              (('IN', 'IN', ','), 418999),
#              (('IN', 'NNP', ','), 419000),
#              (('IN', 'VBZ', ','), 419001),
#              ...])

# %%
print(head, child, a)
# Out:
# DepSample(idx=2, token='Vinken', pos='NNP', head=8) DepSample(idx=6, token='old', pos='JJ', head=2) 187029

# %%
sample
# Out:
# [DepSample(idx=0, token='*', pos='*', head=0),
#  DepSample(idx=1, token='Pierre', pos='NNP', head=2),
#  DepSample(idx=2, token='Vinken', pos='NNP', head=8),
#  DepSample(idx=3, token=',', pos=',', head=2),
#  DepSample(idx=4, token='61', pos='CD', head=5),
#  DepSample(idx=5, token='years', pos='NNS', head=6),
#  DepSample(idx=6, token='old', pos='JJ', head=2),
#  DepSample(idx=7, token=',', pos=',', head=2),
#  DepSample(idx=8, token='will', pos='MD', head=0),
#  DepSample(idx=9, token='join', pos='VB', head=8),
#  DepSample(idx=10, token='the', pos='DT', head=11),
#  DepSample(idx=11, token='board', pos='NN', head=9),
#  DepSample(idx=12, token='as', pos='IN', head=9),
#  DepSample(idx=13, token='a', pos='DT', head=15),
#  DepSample(idx=14, token='nonexecutive', pos='JJ', head=15),
#  DepSample(idx=15, token='director', pos='NN', head=12),
#  DepSample(idx=16, token='Nov.', pos='NNP', head=9),
#  DepSample(idx=17, token='29', pos='CD', head=16),
#  DepSample(idx=18, token='.', pos='.', head=8)]
