# %%
import time
import os
import pickle
import numpy as np
from collections import OrderedDict
from collections import namedtuple
from random import shuffle
import copy
from itertools import combinations, combinations_with_replacement
from utils.utils import ROOT, dep_sample_generator
from typing import List, Dict

# %%
def generate_features_dict(path_to_file, sample2features, start_idx, feature_threshold=0, save_to_file=False,
                           features_name=''):
    """
    This function generates a features dictionary, such that for every features, an index is given starting from start
    the given start_idx.
    The following features are generated for a given dataset:
    byt the given sample2features which is a lambda exprestion to extract a feature from a sample
    you can think of sample2features as a template
    :param: path_to_file: path to location of the dataset (str)
    :param: feature_threshold: if to consider a feature with word that appears less than that in the dataset (int)
    :param: save_to_file: whether or not to save the dictionary on the disk (bool)
    :param: word_hist: dictionary of words histogram in the dataset (dict)
    :return: hw_hp_feat_dict: dictionary feature->index (dict)
    """

    samp_gen = dep_sample_generator(path_to_file)
    hw_hp_feat_dict = OrderedDict()
    features_hist = OrderedDict()

    for s_i, sample in enumerate(samp_gen):
        for s in sample:
            # ignore ROOT
            if s.token == ROOT:
                continue
            

            feats = sample2features(sample, s)
            for feat in feats:
                features_hist[feat] = features_hist.get(feat, 0) + 1

    current_idx = start_idx
    for k, v in features_hist.items():
        if v > feature_threshold:
            hw_hp_feat_dict[k] = current_idx
            current_idx += 1

#     print("total {:} features: ".format(features_name), current_idx)
    hw_hp_feat_dict = OrderedDict(sorted(hw_hp_feat_dict.items(), key=lambda t: t[1]))
    if save_to_file:
        path = path_to_file + features_name + '.dict'
        with open(path, 'wb') as fp:
            pickle.dump(hw_hp_feat_dict, fp)
        print("saved {:} features dictionary @ ".format(features_name), path)
    return hw_hp_feat_dict

# %%
def generate_features_dicts(path_to_file: str, save_to_file: bool =False, minimal: bool=False)->Dict[str, dict]:
    """
    given a training file we return a dictionary of dictionaries
    where key is feature type name, and value is a dictionary of that feature generated by 'generate_features_dict'
    according to feature templates required by hw2 pg 2, those templates are:
    head word _ head pos
    head word
    head pos
    child word _ child pos
    child word
    child pos
    h_pos c_word c_pos

    if not minimal we add:
        h_word h_pos c_word c_pos
        h_word c_word c_pos
        h_word h_pos c_word
        h_word c_word'
    :param path_to_file: training file to extract features from
    :param save_to_file: if to save the dictionary
    :param minimal: if to add the extra features as described
    :return: dictionary described above
    """

    feature_types = {'head word _ head pos': (lambda sample, s: [(sample[s.head].token, sample[s.head].pos)], 0),
                     'head word': (lambda sample, s: [(sample[s.head].token)], 0),
                     'head pos': (lambda sample, s: [(sample[s.head].pos)], 0),
                     'child word _ child pos': (lambda sample, s: [(s.token, s.pos)], 0),
                     'child word': (lambda sample, s: [(s.token)], 0),
                     'child pos': (lambda sample, s: [(s.pos)], 0),
                     'h_pos c_word c_pos': (lambda sample, s: [(sample[s.head].pos, s.token, s.pos)], 0),
                     'h_word h_pos c_pos': (lambda sample, s: [(sample[s.head].token, sample[s.head].pos, s.pos)], 0),
                     'h_pos c_pos': (lambda sample, s: [(sample[s.head].pos, s.pos)], 0),
                     }

    if not minimal:

        feature_types['h_word h_pos c_word c_pos'] = (lambda sample, s:
                                                      [(sample[s.head].token, sample[s.head].pos, s.token, s.pos)], 0)

        feature_types['h_word c_word c_pos'] = (lambda sample, s:
                                                [(sample[s.head].token, s.token, s.pos)], 0)

        feature_types['h_word h_pos c_word'] = (lambda sample, s:
                                                [(sample[s.head].token, sample[s.head].pos, s.token)], 0)

        feature_types['h_word c_word'] = (lambda sample, s:
                                          [(sample[s.head].token, s.token)], 0)

    features_dicts = {}
    current_num_features = 0
    for feature_type_name, (feature_template, feature_threshold) in feature_types.items():

        features_dicts[feature_type_name] = generate_features_dict(path_to_file,
                                                                   feature_template,
                                                                   start_idx=current_num_features,
                                                                   feature_threshold=feature_threshold,
                                                                   save_to_file=False,
                                                                   features_name=feature_type_name)

        num_features = len(features_dicts[feature_type_name])
        current_num_features += num_features

        print('\ngenerated {:} features , num features {:} , total num_features {:}'.format(feature_type_name,
                                                                                         num_features,
                                                                                         current_num_features))

    return features_dicts

# %%
dictionaries = generate_features_dicts('./data/train.labeled.train.labeled')
# Out:
# generated head word _ head pos features , num features 8594 , total num_features 8594
#
# generated head word features , num features 7668 , total num_features 16262
#
# generated head pos features , num features 35 , total num_features 16297
#
# generated child word _ child pos features , num features 13194 , total num_features 29491
#
# generated child word features , num features 11934 , total num_features 41425
#
# generated child pos features , num features 45 , total num_features 41470
#
# generated h_pos c_word c_pos features , num features 25658 , total num_features 67128
#
# generated h_word h_pos c_pos features , num features 28717 , total num_features 95845
#
# generated h_pos c_pos features , num features 693 , total num_features 96538
#
# generated h_word h_pos c_word c_pos features , num features 58080 , total num_features 154618
#
# generated h_word c_word c_pos features , num features 57462 , total num_features 212080
#
# generated h_word h_pos c_word features , num features 57738 , total num_features 269818
#
# generated h_word c_word features , num features 57105 , total num_features 326923

# %%
dictionaries.keys()
# Out:
# dict_keys(['head word _ head pos', 'head word', 'head pos', 'child word _ child pos', 'child word', 'child pos', 'h_pos c_word c_pos', 'h_word h_pos c_pos', 'h_pos c_pos', 'h_word h_pos c_word c_pos', 'h_word c_word c_pos', 'h_word h_pos c_word', 'h_word c_word'])

# %%
sample = next(dep_sample_generator('./data/train.labeled.train.labeled'))
sample
child = sample[6]
head = sample[child.head]

# %%
dict2chick = 'child word _ child pos'

# %%
a = dictionaries['h_word c_word'].get((head.token, child.token))
a
# Out:
# 269823

# %%
dictionaries['h_word c_word']
# Out:
# OrderedDict([(('Vinken', 'Pierre'), 269818),
#              (('will', 'Vinken'), 269819),
#              (('Vinken', ','), 269820),
#              (('years', '61'), 269821),
#              (('old', 'years'), 269822),
#              (('Vinken', 'old'), 269823),
#              (('will', 'join'), 269824),
#              (('board', 'the'), 269825),
#              (('join', 'board'), 269826),
#              (('join', 'as'), 269827),
#              (('director', 'a'), 269828),
#              (('director', 'nonexecutive'), 269829),
#              (('as', 'director'), 269830),
#              (('join', 'Nov.'), 269831),
#              (('Nov.', '29'), 269832),
#              (('will', '.'), 269833),
#              (('Vinken', 'Mr.'), 269834),
#              (('is', 'Vinken'), 269835),
#              (('is', 'chairman'), 269836),
#              (('chairman', 'of'), 269837),
#              (('N.V.', 'Elsevier'), 269838),
#              (('of', 'N.V.'), 269839),
#              (('N.V.', ','), 269840),
#              (('group', 'the'), 269841),
#              (('group', 'Dutch'), 269842),
#              (('group', 'publishing'), 269843),
#              (('N.V.', 'group'), 269844),
#              (('is', '.'), 269845),
#              (('Agnew', 'Rudolph'), 269846),
#              (('was', 'Agnew'), 269847),
#              (('Agnew', ','), 269848),
#              (('years', '55'), 269849),
#              (('Agnew', 'old'), 269850),
#              (('old', 'and'), 269851),
#              (('chairman', 'former'), 269852),
#              (('and', 'chairman'), 269853),
#              (('PLC', 'Consolidated'), 269854),
#              (('PLC', 'Gold'), 269855),
#              (('PLC', 'Fields'), 269856),
#              (('of', 'PLC'), 269857),
#              (('was', 'named'), 269858),
#              (('named', 'director'), 269859),
#              (('director', 'of'), 269860),
#              (('conglomerate', 'this'), 269861),
#              (('conglomerate', 'British'), 269862),
#              (('conglomerate', 'industrial'), 269863),
#              (('of', 'conglomerate'), 269864),
#              (('was', '.'), 269865),
#              (('form', 'A'), 269866),
#              (('has', 'form'), 269867),
#              (('form', 'of'), 269868),
#              (('of', 'asbestos'), 269869),
#              (('used', 'once'), 269870),
#              (('form', 'used'), 269871),
#              (('used', 'to'), 269872),
#              (('to', 'make'), 269873),
#              (('filters', 'Kent'), 269874),
#              (('filters', 'cigarette'), 269875),
#              (('make', 'filters'), 269876),
#              (('reported', 'has'), 269877),
#              (('has', 'caused'), 269878),
#              (('percentage', 'a'), 269879),
#              (('percentage', 'high'), 269880),
#              (('caused', 'percentage'), 269881),
#              (('percentage', 'of'), 269882),
#              (('deaths', 'cancer'), 269883),
#              (('of', 'deaths'), 269884),
#              (('percentage', 'among'), 269885),
#              (('group', 'a'), 269886),
#              (('among', 'group'), 269887),
#              (('group', 'of'), 269888),
#              (('of', 'workers'), 269889),
#              (('workers', 'exposed'), 269890),
#              (('exposed', 'to'), 269891),
#              (('to', 'it'), 269892),
#              (('30', 'more'), 269893),
#              (('30', 'than'), 269894),
#              (('years', '30'), 269895),
#              (('ago', 'years'), 269896),
#              (('exposed', 'ago'), 269897),
#              (('reported', ','), 269898),
#              (('reported', 'researchers'), 269899),
#              (('reported', '.'), 269900),
#              (('fiber', 'The'), 269901),
#              (('fiber', 'asbestos'), 269902),
#              (('is', 'fiber'), 269903),
#              (('fiber', ','), 269904),
#              (('fiber', 'crocidolite'), 269905),
#              (('said', 'is'), 269906),
#              (('resilient', 'unusually'), 269907),
#              (('is', 'resilient'), 269908),
#              (('is', 'once'), 269909),
#              (('enters', 'it'), 269910),
#              (('once', 'enters'), 269911),
#              (('lungs', 'the'), 269912),
#              (('enters', 'lungs'), 269913),
#              (('is', ','), 269914),
#              (('is', 'with'), 269915),
#              (('exposures', 'even'), 269916),
#              (('exposures', 'brief'), 269917),
#              (('causing', 'exposures'), 269918),
#              (('exposures', 'to'), 269919),
#              (('with', 'causing'), 269920),
#              (('causing', 'symptoms'), 269921),
#              (('show', 'that'), 269922),
#              (('symptoms', 'show'), 269923),
#              (('show', 'up'), 269924),
#              (('later', 'decades'), 269925),
#              (('show', 'later'), 269926),
#              (('said', ','), 269927),
#              (('said', 'researchers'), 269928),
#              (('said', '.'), 269929),
#              (('Inc.', 'Lorillard'), 269930),
#              (('stopped', 'Inc.'), 269931),
#              (('Inc.', ','), 269932),
#              (('unit', 'the'), 269933),
#              (('Inc.', 'unit'), 269934),
#              (('unit', 'of'), 269935),
#              (('York-based', 'New'), 269936),
#              (('Corp.', 'York-based'), 269937),
#              (('Corp.', 'Loews'), 269938),
#              (('of', 'Corp.'), 269939),
#              (('makes', 'that'), 269940),
#              (('unit', 'makes'), 269941),
#              (('cigarettes', 'Kent'), 269942),
#              (('makes', 'cigarettes'), 269943),
#              (('stopped', 'using'), 269944),
#              (('using', 'crocidolite'), 269945),
#              (('using', 'in'), 269946),
#              (('filters', 'its'), 269947),
#              (('filters', 'Micronite'), 269948),
#              (('in', 'filters'), 269949),
#              (('in', '1956'), 269950),
#              (('stopped', '.'), 269951),
#              (('appear', 'Although'), 269952),
#              (('findings', 'preliminary'), 269953),
#              (('were', 'findings'), 269954),
#              (('Although', 'were'), 269955),
#              (('were', 'reported'), 269956),
#              (('a', 'more'), 269957),
#              (('a', 'than'), 269958),
#              (('year', 'a'), 269959),
#              (('ago', 'year'), 269960),
#              (('reported', 'ago'), 269961),
#              (('appear', ','), 269962),
#              (('results', 'the'), 269963),
#              (('results', 'latest'), 269964),
#              (('appear', 'results'), 269965),
#              (('appear', 'in'), 269966),
#              (('Journal', 'today'), 269967),
#              (('today', "'s"), 269968),
#              (('Journal', 'New'), 269969),
#              (('Journal', 'England'), 269970),
#              (('in', 'Journal'), 269971),
#              (('Journal', 'of'), 269972),
#              (('of', 'Medicine'), 269973),
#              (('Journal', ','), 269974),
#              (('forum', 'a'), 269975),
#              (('Journal', 'forum'), 269976),
#              (('forum', 'likely'), 269977),
#              (('likely', 'to'), 269978),
#              (('to', 'bring'), 269979),
#              (('attention', 'new'), 269980),
#              (('bring', 'attention'), 269981),
#              (('bring', 'to'), 269982),
#              (('problem', 'the'), 269983),
#              (('to', 'problem'), 269984),
#              (('appear', '.'), 269985),
#              (('spokewoman', 'A'), 269986),
#              (('spokewoman', 'Lorillard'), 269987),
#              (('said', 'spokewoman'), 269988),
#              (('said', '``'), 269989),
#              (('is', 'This'), 269990),
#              (('story', 'an'), 269991),
#              (('story', 'old'), 269992),
#              (('is', 'story'), 269993),
#              (("'re", 'We'), 269994),
#              (("'re", 'talking'), 269995),
#              (('talking', 'about'), 269996),
#              (('about', 'ago'), 269997),
#              (('ago', 'before'), 269998),
#              (('heard', 'anyone'), 269999),
#              (('before', 'heard'), 270000),
#              (('heard', 'of'), 270001),
#              (('having', 'asbestos'), 270002),
#              (('of', 'having'), 270003),
#              (('properties', 'any'), 270004),
#              (('properties', 'questionable'), 270005),
#              (('having', 'properties'), 270006),
#              (("'re", '.'), 270007),
#              (('is', 'There'), 270008),
#              (('asbestos', 'no'), 270009),
#              (('is', 'asbestos'), 270010),
#              (('is', 'in'), 270011),
#              (('products', 'our'), 270012),
#              (('in', 'products'), 270013),
#              (('is', 'now'), 270014),
#              (('is', "''"), 270015),
#              (('Lorillard', 'Neither'), 270016),
#              (('were', 'Lorillard'), 270017),
#              (('Lorillard', 'nor'), 270018),
#              (('researchers', 'the'), 270019),
#              (('nor', 'researchers'), 270020),
#              (('studied', 'who'), 270021),
#              (('researchers', 'studied'), 270022),
#              (('workers', 'the'), 270023),
#              (('studied', 'workers'), 270024),
#              (('were', 'aware'), 270025),
#              (('aware', 'of'), 270026),
#              (('research', 'any'), 270027),
#              (('of', 'research'), 270028),
#              (('research', 'on'), 270029),
#              (('on', 'smokers'), 270030),
#              (('smokers', 'of'), 270031),
#              (('cigarettes', 'the'), 270032),
#              (('of', 'cigarettes'), 270033),
#              (('were', '.'), 270034),
#              (('have', 'We'), 270035),
#              (('said', 'have'), 270036),
#              (('information', 'no'), 270037),
#              (('information', 'useful'), 270038),
#              (('have', 'information'), 270039),
#              (('information', 'on'), 270040),
#              (('on', 'whether'), 270041),
#              (('are', 'users'), 270042),
#              (('whether', 'are'), 270043),
#              (('are', 'at'), 270044),
#              (('at', 'risk'), 270045),
#              (('said', "''"), 270046),
#              (('Talcott', 'James'), 270047),
#              (('Talcott', 'A.'), 270048),
#              (('said', 'Talcott'), 270049),
#              (('Talcott', 'of'), 270050),
#              (('Institute', 'Boston'), 270051),
#              (('Boston', "'s"), 270052),
#              (('Institute', 'Dana-Farber'), 270053),
#              (('Institute', 'Cancer'), 270054),
#              (('of', 'Institute'), 270055),
#              (('Talcott', 'Dr.'), 270056),
#              (('led', 'Talcott'), 270057),
#              (('team', 'a'), 270058),
#              (('led', 'team'), 270059),
#              (('team', 'of'), 270060),
#              (('of', 'researchers'), 270061),
#              (('researchers', 'from'), 270062),
#              (('Institute', 'the'), 270063),
#              (('Institute', 'National'), 270064),
#              (('from', 'Institute'), 270065),
#              (('Institute', 'and'), 270066),
#              (('schools', 'the'), 270067),
#              (('schools', 'medical'), 270068),
#              (('and', 'schools'), 270069),
#              (('schools', 'of'), 270070),
#              (('University', 'Harvard'), 270071),
#              (('of', 'University'), 270072),
#              (('University', 'and'), 270073),
#              (('University', 'Boston'), 270074),
#              (('and', 'University'), 270075),
#              (('led', '.'), 270076),
#              (('spokeswoman', 'The'), 270077),
#              (('spokeswoman', 'Lorillard'), 270078),
#              (('said', 'spokeswoman'), 270079),
#              (('was', 'asbestos'), 270080),
#              (('said', 'was'), 270081),
#              (('was', 'used'), 270082),
#              (('used', 'in'), 270083),
#              (('in', '``'), 270084),
#              (('modest', 'very'), 270085),
#              (('amounts', 'modest'), 270086),
#              (('in', 'amounts'), 270087),
#              (('in', "''"), 270088),
#              (('in', 'making'), 270089),
#              (('making', 'paper'), 270090),
#              (('paper', 'for'), 270091),
#              (('filters', 'the'), 270092),
#              (('for', 'filters'), 270093),
#              (('1950s', 'the'), 270094),
#              (('1950s', 'early'), 270095),
#              (('in', '1950s'), 270096),
#              (('used', 'and'), 270097),
#              (('and', 'replaced'), 270098),
#              (('replaced', 'with'), 270099),
#              (('type', 'a'), 270100),
#              (('type', 'different'), 270101),
#              (('with', 'type'), 270102),
#              (('type', 'of'), 270103),
#              (('of', 'filter'), 270104),
#              (('replaced', 'in'), 270105),
#              (('were', 'From'), 270106),
#              (('From', '1953'), 270107),
#              (('From', 'to'), 270108),
#              (('to', '1955'), 270109),
#              (('were', ','), 270110),
#              (('billion', '9.8'), 270111),
#              (('cigarettes', 'billion'), 270112),
#              (('were', 'cigarettes'), 270113),
#              (('cigarettes', 'with'), 270114),
#              (('with', 'filters'), 270115),
#              (('said', 'were'), 270116),
#              (('were', 'sold'), 270117),
#              (('company', 'the'), 270118),
#              (('said', 'company'), 270119),
#              (('have', 'Among'), 270120),
#              (('men', '33'), 270121),
#              (('Among', 'men'), 270122),
#              (('worked', 'who'), 270123),
#              (('men', 'worked'), 270124),
#              (('worked', 'closely'), 270125),
#              (('worked', 'with'), 270126),
#              (('substance', 'the'), 270127),
#              (('with', 'substance'), 270128),
#              (('have', ','), 270129),
#              (('have', '28'), 270130),
#              (('have', 'died'), 270131),
#              (('died', '--'), 270132),
#              (('times', 'more'), 270133),
#              (('times', 'than'), 270134),
#              (('times', 'three'), 270135),
#              (('number', 'times'), 270136),
#              (('number', 'the'), 270137),
#              (('number', 'expected'), 270138),
#              (('died', 'number'), 270139),
#              (('have', '.'), 270140),
#              (('have', 'Four'), 270141),
#              (('Four', 'of'), 270142),
#              (('workers', 'five'), 270143),
#              (('workers', 'surviving'), 270144),
#              (('diseases', 'asbestos-related'), 270145),
#              (('have', 'diseases'), 270146),
#              (('have', 'including'), 270147),
#              (('including', 'three'), 270148),
#              (('three', 'with'), 270149),
#              (('diagnosed', 'recently'), 270150),
#              (('cancer', 'diagnosed'), 270151),
#              (('with', 'cancer'), 270152),
#              (('total', 'The'), 270153),
#              (('was', 'total'), 270154),
#              (('total', 'of'), 270155),
#              (('deaths', '18'), 270156),
#              (('deaths', 'from'), 270157),
#              (('mesothelioma', 'malignant'), 270158),
#              (('from', 'mesothelioma'), 270159),
#              (('mesothelioma', ','), 270160),
#              (('cancer', 'lung'), 270161),
#              (('mesothelioma', 'cancer'), 270162),
#              (('cancer', 'and'), 270163),
#              (('and', 'asbestosis'), 270164),
#              (('higher', 'far'), 270165),
#              (('was', 'higher'), 270166),
#              (('higher', 'than'), 270167),
#              (('than', 'expected'), 270168),
#              (('rate', 'The'), 270169),
#              (('rate', 'morbidity'), 270170),
#              (('is', 'rate'), 270171),
#              (('finding', 'a'), 270172),
#              (('finding', 'striking'), 270173),
#              (('is', 'finding'), 270174),
#              (('is', 'among'), 270175),
#              (('among', 'those'), 270176),
#              (('those', 'of'), 270177),
#              (('of', 'us'), 270178),
#              (('study', 'who'), 270179),
#              (('those', 'study'), 270180),
#              (('study', 'diseases'), 270181),
#              (('percentage', 'The'), 270182),
#              (('appears', 'percentage'), 270183),
#              (('deaths', 'lung'), 270184),
#              (('among', 'workers'), 270185),
#              (('workers', 'at'), 270186),
#              (('factory', 'the'), 270187),
#              (('Mass.', 'West'), 270188),
#              (('Mass.', 'Groton'), 270189),
#              (('Mass.', ','), 270190),
#              (('factory', 'Mass.'), 270191),
#              (('factory', 'paper'), 270192),
#              (('at', 'factory'), 270193),
#              (('said', 'appears'), 270194),
#              (('appears', 'to'), 270195),
#              (('to', 'be'), 270196),
#              (('highest', 'the'), 270197),
#              (('be', 'highest'), 270198),
#              (('highest', 'for'), 270199),
#              (('workers', 'any'), 270200),
#              (('workers', 'asbestos'), 270201),
#              (('for', 'workers'), 270202),
#              (('workers', 'studied'), 270203),
#              (('studied', 'in'), 270204),
#              (('countries', 'Western'), 270205),
#              (('countries', 'industrialized'), 270206),
#              (('in', 'countries'), 270207),
#              (('said', 'he'), 270208),
#              (('plant', 'The'), 270209),
#              (('was', 'plant'), 270210),
#              (('plant', ','), 270211),
#              (('is', 'which'), 270212),
#              (('plant', 'is'), 270213),
#              (('is', 'owned'), 270214),
#              (('owned', 'by'), 270215),
#              (('Co.', 'Hollingsworth'), 270216),
#              (('Hollingsworth', '&'), 270217),
#              (('&', 'Vose'), 270218),
#              (('by', 'Co.'), 270219),
#              (('was', 'under'), 270220),
#              (('under', 'contract'), 270221),
#              (('contract', 'with'), 270222),
#              (('with', 'Lorillard'), 270223),
#              (('contract', 'to'), 270224),
#              (('finding', 'The'), 270225),
#              (('will', 'finding'), 270226),
#              (('will', 'probably'), 270227),
#              (('said', 'will'), 270228),
#              (('will', 'support'), 270229),
#              (('support', 'those'), 270230),
#              (('argue', 'who'), 270231),
#              (('those', 'argue'), 270232),
#              (('argue', 'that'), 270233),
#              (('U.S.', 'the'), 270234),
#              (('should', 'U.S.'), 270235),
#              (('that', 'should'), 270236),
#              (('should', 'regulate'), 270237),
#              (('class', 'the'), 270238),
#              (('regulate', 'class'), 270239),
#              (('class', 'of'), 270240),
#              (('class', 'including'), 270241),
#              (('including', 'crocidolite'), 270242),
#              (('stringently', 'more'), 270243),
#              (('regulate', 'stringently'), 270244),
#              (('stringently', 'than'), 270245),
#              (('kind', 'the'), 270246),
#              (('kind', 'common'), 270247),
#              (('than', 'kind'), 270248),
#              (('kind', 'of'), 270249),
#              (('kind', ','), 270250),
#              (('kind', 'chrysotile'), 270251),
#              (('kind', 'found'), 270252),
#              (('found', 'in'), 270253),
#              (('schools', 'most'), 270254),
#              (('in', 'schools'), 270255),
#              (('schools', 'and'), 270256),
#              (('buildings', 'other'), 270257),
#              (('and', 'buildings'), 270258),
#              (('U.S.', 'The'), 270259),
#              (('is', 'U.S.'), 270260),
#              (('is', 'one'), 270261),
#              (('one', 'of'), 270262),
#              (('nations', 'the'), 270263),
#              (('nations', 'few'), 270264),
#              (('nations', 'industrialized'), 270265),
#              (('of', 'nations'), 270266),
#              (('does', 'that'), 270267),
#              (('nations', 'does'), 270268),
#              (('does', "n't"), 270269),
#              (('does', 'have'), 270270),
#              (('standard', 'a'), 270271),
#              (('standard', 'higher'), 270272),
#              (('have', 'standard'), 270273),
#              (('standard', 'of'), 270274),
#              (('of', 'regulation'), 270275),
#              (('standard', 'for'), 270276),
#              (('fibers', 'the'), 270277),
#              (('fibers', 'smooth'), 270278),
#              (('fibers', ','), 270279),
#              (('fibers', 'needle-like'), 270280),
#              (('for', 'fibers'), 270281),
#              (('as', 'such'), 270282),
#              (('fibers', 'as'), 270283),
#              (('as', 'crocidolite'), 270284),
#              (('are', 'that'), 270285),
#              (('fibers', 'are'), 270286),
#              (('are', 'classified'), 270287),
#              (('classified', 'as'), 270288),
#              (('as', 'amphobiles'), 270289),
#              (('is', 'according'), 270290),
#              (('according', 'to'), 270291),
#              (('Mossman', 'Brooke'), 270292),
#              (('Mossman', 'T.'), 270293),
#              (('to', 'Mossman'), 270294),
#              (('Mossman', ','), 270295),
#              (('professor', 'a'), 270296),
#              (('Mossman', 'professor'), 270297),
#              (('professor', 'of'), 270298),
#              (('of', 'pathlogy'), 270299),
#              (('professor', 'at'), 270300),
#              (('College', 'the'), 270301),
#              (('College', 'University'), 270302),
#              (('University', 'of'), 270303),
#              (('of', 'Vermont'), 270304),
#              (('at', 'College'), 270305),
#              (('College', 'of'), 270306),
#              (('fibers', 'More'), 270307),
#              (('fibers', 'common'), 270308),
#              (('fibers', 'chrysotile'), 270309),
#              (('are', 'fibers'), 270310),
#              (('explained', 'are'), 270311),
#              (('are', 'curly'), 270312),
#              (('are', 'and'), 270313),
#              (('and', 'are'), 270314),
#              (('easily', 'more'), 270315),
#              (('rejected', 'easily'), 270316),
#              (('are', 'rejected'), 270317),
#              (('rejected', 'by'), 270318),
#              (('body', 'the'), 270319),
#              (('by', 'body'), 270320),
#              (('explained', ','), 270321),
#              (('Mossman', 'Dr.'), 270322),
#              (('explained', 'Mossman'), 270323),
#              (('explained', '.'), 270324),
#              (('imposed', 'In'), 270325),
#              (('In', 'July'), 270326),
#              (('imposed', ','), 270327),
#              (('Agency', 'the'), 270328),
#              (('Agency', 'Environmental'), 270329),
#              (('Agency', 'Protection'), 270330),
#              (('imposed', 'Agency'), 270331),
#              (('ban', 'a'), 270332),
#              (('ban', 'gradual'), 270333),
#              (('imposed', 'ban'), 270334),
#              (('imposed', 'on'), 270335),
#              (('all', 'virtually'), 270336),
#              (('uses', 'all'), 270337),
#              (('on', 'uses'), 270338),
#              (('uses', 'of'), 270339),
#              (('imposed', '.'), 270340),
#              (('will', 'By'), 270341),
#              (('By', '1997'), 270342),
#              (('will', ','), 270343),
#              (('all', 'almost'), 270344),
#              (('uses', 'remaining'), 270345),
#              (('will', 'uses'), 270346),
#              (('asbestos', 'cancer-causing'), 270347),
#              (('will', 'be'), 270348),
#              (('be', 'outlawed'), 270349),
#              (('160', 'About'), 270350),
#              (('workers', '160'), 270351),
#              (('were', 'workers'), 270352),
#              (('factory', 'a'), 270353),
#              (('made', 'that'), 270354),
#              (('factory', 'made'), 270355),
#              (('made', 'paper'), 270356),
#              (('were', 'exposed'), 270357),
#              (('to', 'asbestos'), 270358),
#              (('exposed', 'in'), 270359),
#              (('were', 'Areas'), 270360),
#              (('Areas', 'of'), 270361),
#              (('of', 'factory'), 270362),
#              (('dusty', 'particularly'), 270363),
#              (('were', 'dusty'), 270364),
#              (('was', 'where'), 270365),
#              (('crocidolite', 'the'), 270366),
#              (('was', 'crocidolite'), 270367),
#              (('were', 'was'), 270368),
#              (('dumped', 'Workers'), 270369),
#              (('sacks', 'large'), 270370),
#              (('sacks', 'burlap'), 270371),
#              (('dumped', 'sacks'), 270372),
#              (('sacks', 'of'), 270373),
#              (('material', 'the'), 270374),
#              (('material', 'imported'), 270375),
#              (('of', 'material'), 270376),
#              (('dumped', 'into'), 270377),
#              (('bin', 'a'), 270378),
#              (('bin', 'huge'), 270379),
#              (('into', 'bin'), 270380),
#              (('dumped', ','), 270381),
#              (('dumped', 'poured'), 270382),
#              (('poured', 'in'), 270383),
#              (('fibers', 'cotton'), 270384),
#              (('cotton', 'and'), 270385),
#              (('and', 'acetate'), 270386),
#              (('poured', 'fibers'), 270387),
#              (('poured', 'and'), 270388),
#              (('mixed', 'mechanically'), 270389),
#              (('and', 'mixed'), 270390),
#              (('fibers', 'dry'), 270391),
#              (('mixed', 'fibers'), 270392),
#              (('mixed', 'in'), 270393),
#              (('process', 'a'), 270394),
#              (('in', 'process'), 270395),
#              (('process', 'used'), 270396),
#              (('dumped', '.'), 270397),
#              (('described', 'Workers'), 270398),
#              (('clouds', '``'), 270399),
#              (('described', 'clouds'), 270400),
#              (('clouds', 'of'), 270401),
#              (('dust', 'blue'), 270402),
#              (('of', 'dust'), 270403),
#              (('clouds', "''"), 270404),
#              (('hung', 'that'), 270405),
#              (('clouds', 'hung'), 270406),
#              (('hung', 'over'), 270407),
#              (('over', 'parts'), 270408),
#              (('parts', 'of'), 270409),
#              (('hung', ','), 270410),
#              (('though', 'even'), 270411),
#              (('hung', 'though'), 270412),
#              (('fans', 'exhaust'), 270413),
#              (('ventilated', 'fans'), 270414),
#              (('though', 'ventilated'), 270415),
#              (('area', 'the'), 270416),
#              (('ventilated', 'area'), 270417),
#              (('described', '.'), 270418),
#              (("'s", 'There'), 270419),
#              (('said', "'s"), 270420),
#              (('question', 'no'), 270421),
#              (("'s", 'question'), 270422),
#              (('question', 'that'), 270423),
#              (('contracted', 'some'), 270424),
#              (('some', 'of'), 270425),
#              (('workers', 'those'), 270426),
#              (('workers', 'and'), 270427),
#              (('and', 'managers'), 270428),
#              (('that', 'contracted'), 270429),
#              (('contracted', 'diseases'), 270430),
#              (('Phillips', 'Darrell'), 270431),
#              (('said', 'Phillips'), 270432),
#              (('Phillips', ','), 270433),
#              (('president', 'vice'), 270434),
#              (('Phillips', 'president'), 270435),
#              (('president', 'of'), 270436),
#              (('resources', 'human'), 270437),
#              (('of', 'resources'), 270438),
#              (('president', 'for'), 270439),
#              (('for', 'Hollingsworth'), 270440),
#              (('have', '``'), 270441),
#              (('have', 'But'), 270442),
#              (('have', 'you'), 270443),
#              (('have', 'to'), 270444),
#              (('to', 'recognize'), 270445),
#              (('recognize', 'that'), 270446),
#              (('events', 'these'), 270447),
#              (('took', 'events'), 270448),
#              (('that', 'took'), 270449),
#              (('took', 'place'), 270450),
#              (('years', '35'), 270451),
#              (('took', 'ago'), 270452),
#              (('has', 'It'), 270453),
#              (('bearing', 'no'), 270454),
#              (('has', 'bearing'), 270455),
#              (('bearing', 'on'), 270456),
#              (('force', 'our'), 270457),
#              (('force', 'work'), 270458),
#              (('on', 'force'), 270459),
#              (('force', 'today'), 270460),
#              (('has', '.'), 270461),
#              (('continued', 'Yields'), 270462),
#              (('Yields', 'on'), 270463),
#              (('funds', 'money-market'), 270464),
#              (('funds', 'mutual'), 270465),
#              (('on', 'funds'), 270466),
#              (('continued', 'to'), 270467),
#              (('to', 'slide'), 270468),
#              (('continued', ','), 270469),
#              (('continued', 'amid'), 270470),
#              (('amid', 'signs'), 270471),
#              (('signs', 'that'), 270472),
#              (('managers', 'portfolio'), 270473),
#              (('expect', 'managers'), 270474),
#              (('that', 'expect'), 270475),
#              (('declines', 'further'), 270476),
#              (('expect', 'declines'), 270477),
#              (('declines', 'in'), 270478),
#              (('rates', 'interest'), 270479),
#              (('in', 'rates'), 270480),
#              (('continued', '.'), 270481),
#              (('yield', 'The'), 270482),
#              (('yield', 'average'), 270483),
#              (('yield', 'seven-day'), 270484),
#              (('yield', 'compound'), 270485),
#              (('eased', 'yield'), 270486),
#              (('yield', 'of'), 270487),
#              (('funds', 'the'), 270488),
#              (('funds', '400'), 270489),
#              (('funds', 'taxable'), 270490),
#              (('of', 'funds'), 270491),
#              (('funds', 'tracked'), 270492),
#              (('tracked', 'by'), 270493),
#              (('Report', 'IBC'), 270494),
#              (('IBC', "'s"), 270495),
#              (('Report', 'Money'), 270496),
#              (('Report', 'Fund'), 270497),
#              (('by', 'Report'), 270498),
#              (('fraction', 'a'), 270499),
#              (('eased', 'fraction'), 270500),
#              (('fraction', 'of'), 270501),
#              (('point', 'a'), 270502),
#              (('point', 'percentage'), 270503),
#              (('of', 'point'), 270504),
#              (('eased', 'to'), 270505),
#              (('%', '8.45'), 270506),
#              (('to', '%'), 270507),
#              (('eased', 'from'), 270508),
#              (('%', '8.47'), 270509),
#              (('from', '%'), 270510),
#              (('eased', 'for'), 270511),
#              (('week', 'the'), 270512),
#              (('for', 'week'), 270513),
#              (('week', 'ended'), 270514),
#              (('ended', 'Tuesday'), 270515),
#              (('eased', '.'), 270516),
#              (('yields', 'Compound'), 270517),
#              (('assume', 'yields'), 270518),
#              (('assume', 'reinvestment'), 270519),
#              (('reinvestment', 'of'), 270520),
#              (('of', 'dividends'), 270521),
#              (('reinvestment', 'and'), 270522),
#              (('and', 'that'), 270523),
#              (('yield', 'the'), 270524),
#              (('yield', 'current'), 270525),
#              (('continues', 'yield'), 270526),
#              (('that', 'continues'), 270527),
#              (('continues', 'for'), 270528),
#              (('for', 'year'), 270529),
#              (('assume', '.'), 270530),
#              (('maturity', 'Average'), 270531),
#              (('lengthened', 'maturity'), 270532),
#              (('maturity', 'of'), 270533),
#              (('investments', 'funds'), 270534),
#              (('funds', "'"), 270535),
#              (('of', 'investments'), 270536),
#              (('lengthened', 'by'), 270537),
#              (('day', 'a'), 270538),
#              (('by', 'day'), 270539),
#              (('lengthened', 'to'), 270540),
#              (('days', '41'), 270541),
#              (('to', 'days'), 270542),
#              (('days', ','), 270543),
#              (('longest', 'the'), 270544),
#              (('days', 'longest'), 270545),
#              (('longest', 'since'), 270546),
#              (('August', 'early'), 270547),
#              (('since', 'August'), 270548),
#              (('lengthened', 'according'), 270549),
#              (('to', 'Donoghue'), 270550),
#              (('Donoghue', "'s"), 270551),
#              (('lengthened', '.'), 270552),
#              (('maturities', 'Longer'), 270553),
#              (('are', 'maturities'), 270554),
#              (('are', 'thought'), 270555),
#              (('thought', 'to'), 270556),
#              (('to', 'indicate'), 270557),
#              (('rates', 'declining'), 270558),
#              (('indicate', 'rates'), 270559),
#              (('indicate', 'because'), 270560),
#              (('permit', 'they'), 270561),
#              (('because', 'permit'), 270562),
#              (('to', 'managers'), 270563),
#              (('permit', 'to'), 270564),
#              (('to', 'retain'), 270565),
#              (('rates', 'relatively'), 270566),
#              (('rates', 'higher'), 270567),
#              (('retain', 'rates'), 270568),
#              (('retain', 'for'), 270569),
#              (('period', 'a'), 270570),
#              (('period', 'longer'), 270571),
#              (('for', 'period'), 270572),
#              (('are', '.'), 270573),
#              (('maturities', 'Shorter'), 270574),
#              (('are', 'considered'), 270575),
#              (('sign', 'a'), 270576),
#              (('considered', 'sign'), 270577),
#              (('sign', 'of'), 270578),
#              (('rates', 'rising'), 270579),
#              (('of', 'rates'), 270580),
#              (('considered', 'because'), 270581),
#              (('can', 'managers'), 270582),
#              (('because', 'can'), 270583),
#              (('can', 'capture'), 270584),
#              (('capture', 'rates'), 270585),
#              (('capture', 'sooner'), 270586),
#              (('maturity', 'The'), 270587),
#              (('maturity', 'average'), 270588),
#              (('reached', 'maturity'), 270589),
#              (('maturity', 'for'), 270590),
#              (('for', 'funds'), 270591),
#              (('funds', 'open'), 270592),
#              (('to', 'only'), 270593),
#              (('open', 'to'), 270594),
#              (('to', 'institutions'), 270595),
#              (('maturity', ','), 270596),
#              (('maturity', 'considered'), 270597),
#              (('considered', 'by'), 270598),
#              (('by', 'some'), 270599),
#              (('considered', 'to'), 270600),
#              (('indicator', 'a'), 270601),
#              (('indicator', 'stronger'), 270602),
#              (('be', 'indicator'), 270603),
#              (('be', 'because'), 270604),
#              (('managers', 'those'), 270605),
#              (('watch', 'managers'), 270606),
#              (('because', 'watch'), 270607),
#              (('market', 'the'), 270608),
#              (('watch', 'market'), 270609),
#              (('watch', 'closely'), 270610),
#              (('point', 'high'), 270611),
#              (('reached', 'point'), 270612),
#              (('point', 'for'), 270613),
#              (('year', 'the'), 270614),
#              (('days', '--'), 270615),
#              (('days', '33'), 270616),
#              (('point', 'days'), 270617),
#              (('reached', '.'), 270618),
#              (('may', 'Nevertheless'), 270619),
#              (('may', 'said'), 270620),
#              (('Negus', 'Brenda'), 270621),
#              (('Negus', 'Malizia'), 270622),
#              (('said', 'Negus'), 270623),
#              (('Negus', ','), 270624),
#              (('Negus', 'editor'), 270625),
#              (('editor', 'of'), 270626),
#              (('of', 'Report'), 270627),
#              (('may', 'yields'), 270628),
#              (('may', '``'), 270629),
#              (('may', 'blip'), 270630),
#              (('blip', 'up'), 270631),
#              (('blip', 'again'), 270632),
#              (('blip', 'before'), 270633),
#              (('blip', 'they'), 270634),
#              (('before', 'blip'), 270635),
#              (('blip', 'down'), 270636),
#              (('blip', "''"), 270637),
#              (('blip', 'because'), 270638),
#              (('because', 'of'), 270639),
#              (('rises', 'recent'), 270640),
#              (('because', 'rises'), 270641),
#              (('rises', 'in'), 270642),
#              (('rates', 'short-term'), 270643),
#              (('may', '.'), 270644),
#              (('rose', 'yield'), 270645),
#              (('yield', 'on'), 270646),
#              (('bills', 'six-month'), 270647),
#              (('bills', 'Treasury'), 270648),
#              (('on', 'bills'), 270649),
#              (('bills', 'sold'), 270650),
#              (('sold', 'at'), 270651),
#              (('auction', 'Monday'), 270652),
#              (('Monday', "'s"), 270653),
#              (('at', 'auction'), 270654),
#              (('rose', ','), 270655),
#              (('rose', 'for'), 270656),
#              (('for', 'example'), 270657),
#              (('rose', 'to'), 270658),
#              (('%', '8.04'), 270659),
#              (('rose', 'from'), 270660),
#              (('%', '7.90'), 270661),
#              (('rose', '.'), 270662),
#              (('continue', 'Despite'), 270663),
#              (('declines', 'recent'), 270664),
#              (('Despite', 'declines'), 270665),
#              (('in', 'yields'), 270666),
#              (('continue', ','), 270667),
#              (('continue', 'investors'), 270668),
#              (('continue', 'to'), 270669),
#              (('to', 'pour'), 270670),
#              (('pour', 'cash'), 270671),
#              (('pour', 'into'), 270672),
#              (('funds', 'money'), 270673),
#              (('into', 'funds'), 270674),
#              (('continue', '.'), 270675),
#              (('grew', 'Assets'), 270676),
#              (('Assets', 'of'), 270677),
#              (('grew', 'by'), 270678),
#              (('by', '$'), 270679),
#              (('$', '1.5'), 270680),
#              (('$', 'billion'), 270681),
#              (('grew', 'during'), 270682),
#              (('week', 'latest'), 270683),
#              (('during', 'week'), 270684),
#              (('grew', ','), 270685),
#              (('grew', 'to'), 270686),
#              (('to', '$'), 270687),
#              (('$', '352.7'), 270688),
#              (('grew', '.'), 270689),
#              (('beat', 'Typically'), 270690),
#              (('beat', ','), 270691),
#              (('yields', 'money-fund'), 270692),
#              (('beat', 'yields'), 270693),
#              (('investments', 'comparable'), 270694),
#              (('investments', 'short-term'), 270695),
#              (('beat', 'investments'), 270696),
#              (('beat', 'because'), 270697),
#              (('can', 'vary'), 270698),
#              (('vary', 'maturities'), 270699),
#              (('vary', 'and'), 270700),
#              (('and', 'go'), 270701),
#              (('go', 'after'), 270702),
#              (('rates', 'the'), 270703),
#              (('rates', 'highest'), 270704),
#              (('after', 'rates'), 270705),
#              (('beat', '.'), 270706),
#              (('funds', 'The'), 270707),
#              (('funds', 'top'), 270708),
#              (('are', 'funds'), 270709),
#              (('are', 'currently'), 270710),
#              (('are', 'yielding'), 270711),
#              (('%', 'well'), 270712),
#              (('well', 'over'), 270713),
#              (('well', '9'), 270714),
#              (('yielding', '%'), 270715),
#              (('Dollar', 'Dreyfus'), 270716),
#              (('Dollar', 'World-Wide'), 270717),
#              (('had', 'Dollar'), 270718),
#              (('Dollar', ','), 270719),
#              (('fund', 'the'), 270720),
#              (('fund', 'top-yielding'), 270721),
#              (('Dollar', 'fund'), 270722),
#              (('yield', 'a'), 270723),
#              (('had', 'yield'), 270724),
#              (('%', '9.37'), 270725),
#              (('of', '%'), 270726),
#              (('had', 'during'), 270727),
#              (('had', ','), 270728),
#              (('had', 'down'), 270729),
#              (('down', 'from'), 270730),
#              (('%', '9.45'), 270731),
#              (('week', 'a'), 270732),
#              (('earlier', 'week'), 270733),
#              (('from', 'earlier'), 270734),
#              (('had', '.'), 270735),
#              (('invests', 'It'), 270736),
#              (('invests', 'heavily'), 270737),
#              (('invests', 'in'), 270738),
#              (('securities', 'dollar-denominated'), 270739),
#              (('in', 'securities'), 270740),
#              (('invests', 'overseas'), 270741),
#              (('invests', 'and'), 270742),
#              (('and', 'is'), 270743),
#              (('is', 'currently'), 270744),
#              (('is', 'waiving'), 270745),
#              (('fees', 'management'), 270746),
#              (('waiving', 'fees'), 270747),
#              (('waiving', ','), 270748),
#              (('boosts', 'which'), 270749),
#              (('waiving', 'boosts'), 270750),
#              (('yield', 'its'), 270751),
#              (('boosts', 'yield'), 270752),
#              (('invests', '.'), 270753),
#              (('yield', 'simple'), 270754),
#              (('was', 'yield'), 270755),
#              (('%', '8.12'), 270756),
#              (('was', '%'), 270757),
#              (('was', ','), 270758),
#              (('was', 'down'), 270759),
#              (('%', '8.14'), 270760),
#              (('yield', '30-day'), 270761),
#              (('fell', 'yield'), 270762),
#              (('fell', 'to'), 270763),
#              (('%', 'an'), 270764),
#              (('%', 'average'), 270765),
#              (('%', '8.19'), 270766),
#              (('fell', 'from'), 270767),
#              (('%', '8.22'), 270768),
#              (('fell', ';'), 270769),
#              (('slid', 'yield'), 270770),
#              (('fell', 'slid'), 270771),
#              (('slid', 'to'), 270772),
#              (('%', '8.53'), 270773),
#              (('slid', 'from'), 270774),
#              (('%', '8.56'), 270775),
#              (('fell', '.'), 270776),
#              (('Bolduc', 'J.P.'), 270777),
#              (('was', 'Bolduc'), 270778),
#              (('Bolduc', ','), 270779),
#              (('chairman', 'vice'), 270780),
#              (('Bolduc', 'chairman'), 270781),
#              (('Grace', 'W.R.'), 270782),
#              (('of', 'Grace'), 270783),
#              (('Grace', '&'), 270784),
#              (('&', 'Co.'), 270785),
#              (('Grace', ','), 270786),
#              (('holds', 'which'), 270787),
#              (('Grace', 'holds'), 270788),
#              (('interest', 'a'), 270789),
#              (('%', '83.4'), 270790),
#              (('interest', '%'), 270791),
#              (('holds', 'interest'), 270792),
#              (('interest', 'in'), 270793),
#              (('company', 'this'), 270794),
#              (('company', 'energy-services'), 270795),
#              (('in', 'company'), 270796),
#              (('was', 'elected'), 270797),
#              (('elected', 'director'), 270798),
#              (('succeeds', 'He'), 270799),
#              (('Daniels', 'Terrence'), 270800),
#              (('Daniels', 'D.'), 270801),
#              (('succeeds', 'Daniels'), 270802),
#              (('Daniels', ','), 270803),
#              (('chairman', 'formerly'), 270804),
#              (('chairman', 'a'), 270805),
#              (('chairman', 'W.R.'), 270806),
#              (('chairman', 'Grace'), 270807),
#              (('Daniels', 'chairman'), 270808),
#              (('resigned', 'who'), 270809),
#              (('Daniels', 'resigned'), 270810),
#              (('succeeds', '.'), 270811),
#              (('holds', 'Grace'), 270812),
#              (('holds', 'three'), 270813),
#              (('three', 'of'), 270814),
#              (('Energy', 'Grace'), 270815),
#              (('seats', 'Energy'), 270816),
#              (('Energy', "'s"), 270817),
#              ...])

# %%
print(head, child, a)
# Out:
# DepSample(idx=2, token='Vinken', pos='NNP', head=8) DepSample(idx=6, token='old', pos='JJ', head=2) 269823
